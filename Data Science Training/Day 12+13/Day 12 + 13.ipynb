# %% [markdown]
# # Pandas, Matplotlib and Seaborn

# %%
# fillna
# replace
# drop
# drop_duplicates
# outliers detection
# pivot table

# Matplotlib Charts
'''Bar, Pie, Line, Box, violin'''
# Seaborn Charts
'''Bar,Line,Heatmap,Box,Violin,CatPlot,Regplolt,lmplot'''
#Feature Engineering
print('Topics for Today')
# Out:
# Topics for Today

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("patrickb1912/ipl-complete-dataset-20082020")

print("Path to dataset files:", path)
# Out:
# Path to dataset files: /Users/utkarshtripathi24/.cache/kagglehub/datasets/patrickb1912/ipl-complete-dataset-20082020/versions/3

# %%
import os
file_one,file_two = os.listdir(path)
print('Done')
# Out:
# Done

# %%
file_one_path = path + '/' + file_one # also can use '\\' or '/'
file_two_path = path + '/' + file_two # also can use '\\' or '/'

# %%
print(file_one_path)
print(file_two_path)
# Out:
# /Users/utkarshtripathi24/.cache/kagglehub/datasets/patrickb1912/ipl-complete-dataset-20082020/versions/3/matches.csv
# /Users/utkarshtripathi24/.cache/kagglehub/datasets/patrickb1912/ipl-complete-dataset-20082020/versions/3/deliveries.csv

# %%
# Step1 : Modules Import
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
print('Done')
# Out:
# Done

# %%
df_matches = pd.read_csv(file_one_path)
df_deliveries = pd.read_csv(file_two_path)

print('Done')
# Out:
# Done

# %%
# EDA
df_matches.head(2)
# Out:
#        id   season        city        date match_type player_of_match  \
# 0  335982  2007/08   Bangalore  2008-04-18     League     BB McCullum
# 1  335983  2007/08  Chandigarh  2008-04-19     League      MEK Hussey
#
#                                         venue                        team1  \
# 0                       M Chinnaswamy Stadium  Royal Challengers Bangalore
# 1  Punjab Cricket Association Stadium, Mohali              Kings XI Punjab
#
#                    team2                  toss_winner toss_decision  \
# 0  Kolkata Knight Riders  Royal Challengers Bangalore         field
# 1    Chennai Super Kings          Chennai Super Kings           bat
#
#                   winner result  result_margin  target_runs  target_overs  \
# 0  Kolkata Knight Riders   runs          140.0        223.0          20.0
# 1    Chennai Super Kings   runs           33.0        241.0          20.0
#
#   super_over method    umpire1      umpire2
# 0          N    NaN  Asad Rauf  RE Koertzen
# 1          N    NaN  MR Benson   SL Shastri

# %%
df_deliveries.head(2)
# Out:
#    match_id  inning           batting_team                 bowling_team  over  \
# 0    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 1    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
#
#    ball       batter   bowler  non_striker  batsman_runs  extra_runs  \
# 0     1   SC Ganguly  P Kumar  BB McCullum             0           1
# 1     2  BB McCullum  P Kumar   SC Ganguly             0           0
#
#    total_runs extras_type  is_wicket player_dismissed dismissal_kind fielder
# 0           1     legbyes          0              NaN            NaN     NaN
# 1           0         NaN          0              NaN            NaN     NaN

# %%
df_matches.shape
# Out:
# (1095, 20)

# %%
df_deliveries.shape
# Out:
# (260920, 17)

# %%
# Info

# %%
df_matches.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1095 entries, 0 to 1094
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               1095 non-null   int64
#  1   season           1095 non-null   object
#  2   city             1044 non-null   object
#  3   date             1095 non-null   object
#  4   match_type       1095 non-null   object
#  5   player_of_match  1090 non-null   object
#  6   venue            1095 non-null   object
#  7   team1            1095 non-null   object
#  8   team2            1095 non-null   object
#  9   toss_winner      1095 non-null   object
#  10  toss_decision    1095 non-null   object
#  11  winner           1090 non-null   object
#  12  result           1095 non-null   object
#  13  result_margin    1076 non-null   float64
#  14  target_runs      1092 non-null   float64
#  15  target_overs     1092 non-null   float64
#  16  super_over       1095 non-null   object
#  17  method           21 non-null     object
#  18  umpire1          1095 non-null   object
#  19  umpire2          1095 non-null   object
# dtypes: float64(3), int64(1), object(16)
# memory usage: 171.2+ KB

# %%
# columns
df_matches.columns
# Out:
# Index(['id', 'season', 'city', 'date', 'match_type', 'player_of_match',
#        'venue', 'team1', 'team2', 'toss_winner', 'toss_decision', 'winner',
#        'result', 'result_margin', 'target_runs', 'target_overs', 'super_over',
#        'method', 'umpire1', 'umpire2'],
#       dtype='object')

# %%
# Nullvalues count
df_matches.isna().sum().sort_values(ascending = False)
# Out:
# method             1074
# city                 51
# result_margin        19
# winner                5
# player_of_match       5
# target_overs          3
# target_runs           3
# id                    0
# umpire1               0
# super_over            0
# result                0
# toss_decision         0
# season                0
# toss_winner           0
# team2                 0
# team1                 0
# venue                 0
# match_type            0
# date                  0
# umpire2               0
# dtype: int64

# %%
# Heatmap

sns.heatmap(df_matches.isna())
plt.show()

# %%
# Nullvalues count
df_matches.isna().mean().sort_values(ascending = False)*100
# Out:
# method             98.082192
# city                4.657534
# result_margin       1.735160
# winner              0.456621
# player_of_match     0.456621
# target_overs        0.273973
# target_runs         0.273973
# id                  0.000000
# umpire1             0.000000
# super_over          0.000000
# result              0.000000
# toss_decision       0.000000
# season              0.000000
# toss_winner         0.000000
# team2               0.000000
# team1               0.000000
# venue               0.000000
# match_type          0.000000
# date                0.000000
# umpire2             0.000000
# dtype: float64

# %%
df_matches['method'].value_counts()
# Out:
# method
# D/L    21
# Name: count, dtype: int64

# %%
df_matches['method'].fillna('Normal method',inplace = True)
print('Done')
# Out:
# Done
# /var/folders/y0/tq9y6qys5zx8m8_x74cgbd040000gn/T/ipykernel_51351/3682990747.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_matches['method'].fillna('Normal method',inplace = True)

# %%
df_matches['city'].value_counts()
# Out:
# city
# Mumbai            173
# Kolkata            93
# Delhi              90
# Chennai            85
# Hyderabad          77
# Bangalore          65
# Chandigarh         61
# Jaipur             57
# Pune               51
# Abu Dhabi          37
# Ahmedabad          36
# Bengaluru          29
# Durban             15
# Visakhapatnam      15
# Lucknow            14
# Dubai              13
# Dharamsala         13
# Centurion          12
# Rajkot             10
# Sharjah            10
# Indore              9
# Navi Mumbai         9
# Johannesburg        8
# Cuttack             7
# Port Elizabeth      7
# Ranchi              7
# Cape Town           7
# Raipur              6
# Mohali              5
# Kochi               5
# Kanpur              4
# Kimberley           3
# East London         3
# Guwahati            3
# Nagpur              3
# Bloemfontein        2
# Name: count, dtype: int64

# %%
# masking
df_matches[df_matches['city'].isna()]
# Out:
#           id   season city        date   match_type player_of_match  \
# 399   729281     2014  NaN  2014-04-17       League       YS Chahal
# 402   729287     2014  NaN  2014-04-19       League        PA Patel
# 403   729289     2014  NaN  2014-04-19       League       JP Duminy
# 404   729291     2014  NaN  2014-04-20       League      GJ Maxwell
# 406   729295     2014  NaN  2014-04-22       League      GJ Maxwell
# 407   729297     2014  NaN  2014-04-23       League       RA Jadeja
# 408   729299     2014  NaN  2014-04-24       League         CA Lynn
# 409   729301     2014  NaN  2014-04-25       League        AJ Finch
# 410   729303     2014  NaN  2014-04-25       League       MM Sharma
# 413   729309     2014  NaN  2014-04-27       League         M Vijay
# 414   729311     2014  NaN  2014-04-27       League        DR Smith
# 415   729313     2014  NaN  2014-04-28       League  Sandeep Sharma
# 417   729317     2014  NaN  2014-04-30       League         B Kumar
# 757  1216493  2020/21  NaN  2020-09-20       League      MP Stoinis
# 758  1216534  2020/21  NaN  2020-09-21       League       YS Chahal
# 759  1216496  2020/21  NaN  2020-09-22       League       SV Samson
# 761  1216510  2020/21  NaN  2020-09-24       League        KL Rahul
# 762  1216539  2020/21  NaN  2020-09-25       League         PP Shaw
# 764  1216527  2020/21  NaN  2020-09-27       League       SV Samson
# 765  1216547  2020/21  NaN  2020-09-28       League  AB de Villiers
# 767  1216504  2020/21  NaN  2020-09-30       League     Shivam Mavi
# 769  1216516  2020/21  NaN  2020-10-02       League         PK Garg
# 771  1216515  2020/21  NaN  2020-10-03       League         SS Iyer
# 772  1216513  2020/21  NaN  2020-10-04       League       SR Watson
# 773  1216538  2020/21  NaN  2020-10-04       League        TA Boult
# 774  1216519  2020/21  NaN  2020-10-05       League        AR Patel
# 777  1216542  2020/21  NaN  2020-10-08       League     JM Bairstow
# 778  1216500  2020/21  NaN  2020-10-09       League        R Ashwin
# 780  1216525  2020/21  NaN  2020-10-10       League         V Kohli
# 781  1216507  2020/21  NaN  2020-10-11       League       R Tewatia
# 783  1216540  2020/21  NaN  2020-10-12       League  AB de Villiers
# 784  1216528  2020/21  NaN  2020-10-13       League       RA Jadeja
# 785  1216543  2020/21  NaN  2020-10-14       League        A Nortje
# 786  1216531  2020/21  NaN  2020-10-15       League        KL Rahul
# 788  1216509  2020/21  NaN  2020-10-17       League        S Dhawan
# 789  1216522  2020/21  NaN  2020-10-17       League  AB de Villiers
# 791  1216517  2020/21  NaN  2020-10-18       League        KL Rahul
# 793  1216546  2020/21  NaN  2020-10-20       League        S Dhawan
# 795  1216518  2020/21  NaN  2020-10-22       League       MK Pandey
# 796  1216521  2020/21  NaN  2020-10-23       League        TA Boult
# 798  1216498  2020/21  NaN  2020-10-24       League       CJ Jordan
# 800  1216544  2020/21  NaN  2020-10-25       League      RD Gaikwad
# 801  1216520  2020/21  NaN  2020-10-26       League        CH Gayle
# 802  1216524  2020/21  NaN  2020-10-27       League         WP Saha
# 804  1216536  2020/21  NaN  2020-10-29       League      RD Gaikwad
# 806  1216502  2020/21  NaN  2020-10-31       League  Sandeep Sharma
# 807  1216535  2020/21  NaN  2020-10-31       League    Ishan Kishan
# 809  1216530  2020/21  NaN  2020-11-01       League      PJ Cummins
# 811  1216495  2020/21  NaN  2020-11-03       League        S Nadeem
# 812  1237177  2020/21  NaN  2020-11-05  Qualifier 1       JJ Bumrah
# 815  1237181  2020/21  NaN  2020-11-10        Final        TA Boult
#
#                                    venue                        team1  \
# 399              Sharjah Cricket Stadium             Delhi Daredevils
# 402  Dubai International Cricket Stadium  Royal Challengers Bangalore
# 403  Dubai International Cricket Stadium        Kolkata Knight Riders
# 404              Sharjah Cricket Stadium             Rajasthan Royals
# 406              Sharjah Cricket Stadium              Kings XI Punjab
# 407  Dubai International Cricket Stadium             Rajasthan Royals
# 408              Sharjah Cricket Stadium  Royal Challengers Bangalore
# 409  Dubai International Cricket Stadium          Sunrisers Hyderabad
# 410  Dubai International Cricket Stadium          Chennai Super Kings
# 413              Sharjah Cricket Stadium             Delhi Daredevils
# 414              Sharjah Cricket Stadium          Sunrisers Hyderabad
# 415  Dubai International Cricket Stadium              Kings XI Punjab
# 417  Dubai International Cricket Stadium               Mumbai Indians
# 757  Dubai International Cricket Stadium               Delhi Capitals
# 758  Dubai International Cricket Stadium  Royal Challengers Bangalore
# 759              Sharjah Cricket Stadium             Rajasthan Royals
# 761  Dubai International Cricket Stadium              Kings XI Punjab
# 762  Dubai International Cricket Stadium               Delhi Capitals
# 764              Sharjah Cricket Stadium              Kings XI Punjab
# 765  Dubai International Cricket Stadium  Royal Challengers Bangalore
# 767  Dubai International Cricket Stadium        Kolkata Knight Riders
# 769  Dubai International Cricket Stadium          Sunrisers Hyderabad
# 771              Sharjah Cricket Stadium               Delhi Capitals
# 772  Dubai International Cricket Stadium              Kings XI Punjab
# 773              Sharjah Cricket Stadium               Mumbai Indians
# 774  Dubai International Cricket Stadium               Delhi Capitals
# 777  Dubai International Cricket Stadium          Sunrisers Hyderabad
# 778              Sharjah Cricket Stadium               Delhi Capitals
# 780  Dubai International Cricket Stadium  Royal Challengers Bangalore
# 781  Dubai International Cricket Stadium          Sunrisers Hyderabad
# 783              Sharjah Cricket Stadium  Royal Challengers Bangalore
# 784  Dubai International Cricket Stadium          Chennai Super Kings
# 785  Dubai International Cricket Stadium               Delhi Capitals
# 786              Sharjah Cricket Stadium  Royal Challengers Bangalore
# 788              Sharjah Cricket Stadium          Chennai Super Kings
# 789  Dubai International Cricket Stadium             Rajasthan Royals
# 791  Dubai International Cricket Stadium               Mumbai Indians
# 793  Dubai International Cricket Stadium               Delhi Capitals
# 795  Dubai International Cricket Stadium             Rajasthan Royals
# 796              Sharjah Cricket Stadium          Chennai Super Kings
# 798  Dubai International Cricket Stadium              Kings XI Punjab
# 800  Dubai International Cricket Stadium  Royal Challengers Bangalore
# 801              Sharjah Cricket Stadium        Kolkata Knight Riders
# 802  Dubai International Cricket Stadium          Sunrisers Hyderabad
# 804  Dubai International Cricket Stadium        Kolkata Knight Riders
# 806              Sharjah Cricket Stadium  Royal Challengers Bangalore
# 807  Dubai International Cricket Stadium               Delhi Capitals
# 809  Dubai International Cricket Stadium        Kolkata Knight Riders
# 811              Sharjah Cricket Stadium               Mumbai Indians
# 812  Dubai International Cricket Stadium               Mumbai Indians
# 815  Dubai International Cricket Stadium               Delhi Capitals
#
#                            team2                  toss_winner toss_decision  \
# 399  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 402               Mumbai Indians  Royal Challengers Bangalore         field
# 403             Delhi Daredevils        Kolkata Knight Riders           bat
# 404              Kings XI Punjab              Kings XI Punjab         field
# 406          Sunrisers Hyderabad          Sunrisers Hyderabad         field
# 407          Chennai Super Kings             Rajasthan Royals         field
# 408        Kolkata Knight Riders  Royal Challengers Bangalore         field
# 409             Delhi Daredevils          Sunrisers Hyderabad           bat
# 410               Mumbai Indians               Mumbai Indians           bat
# 413               Mumbai Indians               Mumbai Indians           bat
# 414          Chennai Super Kings          Sunrisers Hyderabad           bat
# 415  Royal Challengers Bangalore              Kings XI Punjab         field
# 417          Sunrisers Hyderabad               Mumbai Indians         field
# 757              Kings XI Punjab              Kings XI Punjab         field
# 758          Sunrisers Hyderabad          Sunrisers Hyderabad         field
# 759          Chennai Super Kings          Chennai Super Kings         field
# 761  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 762          Chennai Super Kings          Chennai Super Kings         field
# 764             Rajasthan Royals             Rajasthan Royals         field
# 765               Mumbai Indians               Mumbai Indians         field
# 767             Rajasthan Royals             Rajasthan Royals         field
# 769          Chennai Super Kings          Sunrisers Hyderabad           bat
# 771        Kolkata Knight Riders        Kolkata Knight Riders         field
# 772          Chennai Super Kings              Kings XI Punjab           bat
# 773          Sunrisers Hyderabad               Mumbai Indians           bat
# 774  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 777              Kings XI Punjab          Sunrisers Hyderabad           bat
# 778             Rajasthan Royals             Rajasthan Royals         field
# 780          Chennai Super Kings  Royal Challengers Bangalore           bat
# 781             Rajasthan Royals          Sunrisers Hyderabad           bat
# 783        Kolkata Knight Riders  Royal Challengers Bangalore           bat
# 784          Sunrisers Hyderabad          Chennai Super Kings           bat
# 785             Rajasthan Royals               Delhi Capitals           bat
# 786              Kings XI Punjab  Royal Challengers Bangalore           bat
# 788               Delhi Capitals          Chennai Super Kings           bat
# 789  Royal Challengers Bangalore             Rajasthan Royals           bat
# 791              Kings XI Punjab               Mumbai Indians           bat
# 793              Kings XI Punjab               Delhi Capitals           bat
# 795          Sunrisers Hyderabad          Sunrisers Hyderabad         field
# 796               Mumbai Indians               Mumbai Indians         field
# 798          Sunrisers Hyderabad          Sunrisers Hyderabad         field
# 800          Chennai Super Kings  Royal Challengers Bangalore           bat
# 801              Kings XI Punjab              Kings XI Punjab         field
# 802               Delhi Capitals               Delhi Capitals         field
# 804          Chennai Super Kings          Chennai Super Kings         field
# 806          Sunrisers Hyderabad          Sunrisers Hyderabad         field
# 807               Mumbai Indians               Mumbai Indians         field
# 809             Rajasthan Royals             Rajasthan Royals         field
# 811          Sunrisers Hyderabad          Sunrisers Hyderabad         field
# 812               Delhi Capitals               Delhi Capitals         field
# 815               Mumbai Indians               Delhi Capitals           bat
#
#                           winner   result  result_margin  target_runs  \
# 399  Royal Challengers Bangalore  wickets            8.0        146.0
# 402  Royal Challengers Bangalore  wickets            7.0        116.0
# 403             Delhi Daredevils  wickets            4.0        167.0
# 404              Kings XI Punjab  wickets            7.0        192.0
# 406              Kings XI Punjab     runs           72.0        194.0
# 407          Chennai Super Kings     runs            7.0        141.0
# 408        Kolkata Knight Riders     runs            2.0        151.0
# 409          Sunrisers Hyderabad     runs            4.0        185.0
# 410          Chennai Super Kings  wickets            7.0        142.0
# 413             Delhi Daredevils  wickets            6.0        126.0
# 414          Chennai Super Kings  wickets            5.0        146.0
# 415              Kings XI Punjab  wickets            5.0        125.0
# 417          Sunrisers Hyderabad     runs           15.0        173.0
# 757               Delhi Capitals      tie            NaN        158.0
# 758  Royal Challengers Bangalore     runs           10.0        164.0
# 759             Rajasthan Royals     runs           16.0        217.0
# 761              Kings XI Punjab     runs           97.0        207.0
# 762               Delhi Capitals     runs           44.0        176.0
# 764             Rajasthan Royals  wickets            4.0        224.0
# 765  Royal Challengers Bangalore      tie            NaN        202.0
# 767        Kolkata Knight Riders     runs           37.0        175.0
# 769          Sunrisers Hyderabad     runs            7.0        165.0
# 771               Delhi Capitals     runs           18.0        229.0
# 772          Chennai Super Kings  wickets           10.0        179.0
# 773               Mumbai Indians     runs           34.0        209.0
# 774               Delhi Capitals     runs           59.0        197.0
# 777          Sunrisers Hyderabad     runs           69.0        202.0
# 778               Delhi Capitals     runs           46.0        185.0
# 780  Royal Challengers Bangalore     runs           37.0        170.0
# 781             Rajasthan Royals  wickets            5.0        159.0
# 783  Royal Challengers Bangalore     runs           82.0        195.0
# 784          Chennai Super Kings     runs           20.0        168.0
# 785               Delhi Capitals     runs           13.0        162.0
# 786              Kings XI Punjab  wickets            8.0        172.0
# 788               Delhi Capitals  wickets            5.0        180.0
# 789  Royal Challengers Bangalore  wickets            7.0        178.0
# 791              Kings XI Punjab      tie            NaN        177.0
# 793              Kings XI Punjab  wickets            5.0        165.0
# 795          Sunrisers Hyderabad  wickets            8.0        155.0
# 796               Mumbai Indians  wickets           10.0        115.0
# 798              Kings XI Punjab     runs           12.0        127.0
# 800          Chennai Super Kings  wickets            8.0        146.0
# 801              Kings XI Punjab  wickets            8.0        150.0
# 802          Sunrisers Hyderabad     runs           88.0        220.0
# 804          Chennai Super Kings  wickets            6.0        173.0
# 806          Sunrisers Hyderabad  wickets            5.0        121.0
# 807               Mumbai Indians  wickets            9.0        111.0
# 809        Kolkata Knight Riders     runs           60.0        192.0
# 811          Sunrisers Hyderabad  wickets           10.0        150.0
# 812               Mumbai Indians     runs           57.0        201.0
# 815               Mumbai Indians  wickets            5.0        157.0
#
#      target_overs super_over         method                umpire1  \
# 399          20.0          N  Normal method              Aleem Dar
# 402          20.0          N  Normal method              Aleem Dar
# 403          20.0          N  Normal method              Aleem Dar
# 404          20.0          N  Normal method              BF Bowden
# 406          20.0          N  Normal method              M Erasmus
# 407          20.0          N  Normal method        HDPK Dharmasena
# 408          20.0          N  Normal method              Aleem Dar
# 409          20.0          N  Normal method              M Erasmus
# 410          20.0          N  Normal method              BF Bowden
# 413          20.0          N  Normal method              Aleem Dar
# 414          20.0          N  Normal method           AK Chaudhary
# 415          20.0          N  Normal method              BF Bowden
# 417          20.0          N  Normal method        HDPK Dharmasena
# 757          20.0          Y  Normal method           AK Chaudhary
# 758          20.0          N  Normal method            AY Dandekar
# 759          20.0          N  Normal method          C Shamshuddin
# 761          20.0          N  Normal method           AK Chaudhary
# 762          20.0          N  Normal method  KN Ananthapadmanabhan
# 764          20.0          N  Normal method         RK Illingworth
# 765          20.0          Y  Normal method            Nitin Menon
# 767          20.0          N  Normal method  KN Ananthapadmanabhan
# 769          20.0          N  Normal method           AK Chaudhary
# 771          20.0          N  Normal method            VA Kulkarni
# 772          20.0          N  Normal method            AY Dandekar
# 773          20.0          N  Normal method  KN Ananthapadmanabhan
# 774          20.0          N  Normal method            Nitin Menon
# 777          20.0          N  Normal method           AK Chaudhary
# 778          20.0          N  Normal method  KN Ananthapadmanabhan
# 780          20.0          N  Normal method           AK Chaudhary
# 781          20.0          N  Normal method               YC Barde
# 783          20.0          N  Normal method         RK Illingworth
# 784          20.0          N  Normal method           AK Chaudhary
# 785          20.0          N  Normal method           AK Chaudhary
# 786          20.0          N  Normal method  KN Ananthapadmanabhan
# 788          20.0          N  Normal method  KN Ananthapadmanabhan
# 789          20.0          N  Normal method           AK Chaudhary
# 791          20.0          Y  Normal method            Nitin Menon
# 793          20.0          N  Normal method          C Shamshuddin
# 795          20.0          N  Normal method            Nitin Menon
# 796          20.0          N  Normal method          C Shamshuddin
# 798          20.0          N  Normal method            AY Dandekar
# 800          20.0          N  Normal method          C Shamshuddin
# 801          20.0          N  Normal method  KN Ananthapadmanabhan
# 802          20.0          N  Normal method           AK Chaudhary
# 804          20.0          N  Normal method          C Shamshuddin
# 806          20.0          N  Normal method  KN Ananthapadmanabhan
# 807          20.0          N  Normal method               YC Barde
# 809          20.0          N  Normal method            Nitin Menon
# 811          20.0          N  Normal method          C Shamshuddin
# 812          20.0          N  Normal method            CB Gaffaney
# 815          20.0          N  Normal method            CB Gaffaney
#
#             umpire2
# 399          S Ravi
# 402    AK Chaudhary
# 403     VA Kulkarni
# 404       M Erasmus
# 406          S Ravi
# 407  RK Illingworth
# 408     VA Kulkarni
# 409          S Ravi
# 410       M Erasmus
# 413     VA Kulkarni
# 414     VA Kulkarni
# 415          S Ravi
# 417       M Erasmus
# 757     Nitin Menon
# 758     Nitin Menon
# 759     VA Kulkarni
# 761      PR Reiffel
# 762  RK Illingworth
# 764    K Srinivasan
# 765      PR Reiffel
# 767   C Shamshuddin
# 769      PR Reiffel
# 771  RK Illingworth
# 772     Nitin Menon
# 773  RK Illingworth
# 774        YC Barde
# 777     Nitin Menon
# 778   C Shamshuddin
# 780      PR Reiffel
# 781      PR Reiffel
# 783    K Srinivasan
# 784      PR Reiffel
# 785     Nitin Menon
# 786   C Shamshuddin
# 788  RK Illingworth
# 789     Nitin Menon
# 791      PR Reiffel
# 793  RK Illingworth
# 795      PR Reiffel
# 796     VA Kulkarni
# 798      PR Reiffel
# 800  RK Illingworth
# 801  RK Illingworth
# 802     Nitin Menon
# 804  RK Illingworth
# 806    K Srinivasan
# 807      PR Reiffel
# 809      PR Reiffel
# 811  RK Illingworth
# 812     Nitin Menon
# 815     Nitin Menon

# %%
df_matches['city'].fillna('UAE', inplace = True)
print('done')
# Out:
# done
# /var/folders/y0/tq9y6qys5zx8m8_x74cgbd040000gn/T/ipykernel_51351/2013551467.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_matches['city'].fillna('UAE', inplace = True)

# %%
# Nullvalues count
df_matches.isna().mean().sort_values(ascending = False)*100
# Out:
# result_margin      1.735160
# winner             0.456621
# player_of_match    0.456621
# target_overs       0.273973
# target_runs        0.273973
# id                 0.000000
# umpire1            0.000000
# method             0.000000
# super_over         0.000000
# result             0.000000
# toss_decision      0.000000
# season             0.000000
# toss_winner        0.000000
# team2              0.000000
# team1              0.000000
# venue              0.000000
# match_type         0.000000
# date               0.000000
# city               0.000000
# umpire2            0.000000
# dtype: float64

# %%
df_matches[df_matches['result_margin'].isna()]
# Out:
#           id   season       city        date match_type player_of_match  \
# 66    392190     2009  Cape Town  2009-04-23     League       YK Pathan
# 130   419121  2009/10    Chennai  2010-03-21     League        J Theron
# 241   501265     2011      Delhi  2011-05-21     League             NaN
# 328   598004     2013  Hyderabad  2013-04-07     League       GH Vihari
# 342   598017     2013  Bangalore  2013-04-16     League         V Kohli
# 416   729315     2014  Abu Dhabi  2014-04-29     League     JP Faulkner
# 475   829741     2015  Ahmedabad  2015-04-21     League        SE Marsh
# 485   829763     2015  Bangalore  2015-04-29     League             NaN
# 511   829813     2015  Bangalore  2015-05-17     League             NaN
# 610  1082625     2017     Rajkot  2017-04-29     League       KH Pandya
# 705  1175365     2019      Delhi  2019-03-30     League         PP Shaw
# 744  1178424     2019  Bengaluru  2019-04-30     League             NaN
# 746  1178426     2019     Mumbai  2019-05-02     League       JJ Bumrah
# 757  1216493  2020/21        UAE  2020-09-20     League      MP Stoinis
# 765  1216547  2020/21        UAE  2020-09-28     League  AB de Villiers
# 790  1216512  2020/21  Abu Dhabi  2020-10-18     League     LH Ferguson
# 791  1216517  2020/21        UAE  2020-10-18     League        KL Rahul
# 835  1254077     2021    Chennai  2021-04-25     League         PP Shaw
# 994  1359519     2023    Lucknow  2023-05-03     League             NaN
#
#                                                  venue  \
# 66                                            Newlands
# 130                    MA Chidambaram Stadium, Chepauk
# 241                                   Feroz Shah Kotla
# 328          Rajiv Gandhi International Stadium, Uppal
# 342                              M Chinnaswamy Stadium
# 416                               Sheikh Zayed Stadium
# 475                       Sardar Patel Stadium, Motera
# 485                              M Chinnaswamy Stadium
# 511                              M Chinnaswamy Stadium
# 610             Saurashtra Cricket Association Stadium
# 705                               Arun Jaitley Stadium
# 744                              M.Chinnaswamy Stadium
# 746                                   Wankhede Stadium
# 757                Dubai International Cricket Stadium
# 765                Dubai International Cricket Stadium
# 790                               Sheikh Zayed Stadium
# 791                Dubai International Cricket Stadium
# 835           MA Chidambaram Stadium, Chepauk, Chennai
# 994  Bharat Ratna Shri Atal Bihari Vajpayee Ekana C...
#
#                            team1                        team2  \
# 66         Kolkata Knight Riders             Rajasthan Royals
# 130          Chennai Super Kings              Kings XI Punjab
# 241             Delhi Daredevils                Pune Warriors
# 328          Sunrisers Hyderabad  Royal Challengers Bangalore
# 342  Royal Challengers Bangalore             Delhi Daredevils
# 416        Kolkata Knight Riders             Rajasthan Royals
# 475             Rajasthan Royals              Kings XI Punjab
# 485  Royal Challengers Bangalore             Rajasthan Royals
# 511  Royal Challengers Bangalore             Delhi Daredevils
# 610                Gujarat Lions               Mumbai Indians
# 705        Kolkata Knight Riders               Delhi Capitals
# 744  Royal Challengers Bangalore             Rajasthan Royals
# 746               Mumbai Indians          Sunrisers Hyderabad
# 757               Delhi Capitals              Kings XI Punjab
# 765  Royal Challengers Bangalore               Mumbai Indians
# 790        Kolkata Knight Riders          Sunrisers Hyderabad
# 791               Mumbai Indians              Kings XI Punjab
# 835               Delhi Capitals          Sunrisers Hyderabad
# 994         Lucknow Super Giants          Chennai Super Kings
#
#                      toss_winner toss_decision                       winner  \
# 66         Kolkata Knight Riders         field             Rajasthan Royals
# 130          Chennai Super Kings         field              Kings XI Punjab
# 241             Delhi Daredevils           bat                          NaN
# 328  Royal Challengers Bangalore           bat          Sunrisers Hyderabad
# 342  Royal Challengers Bangalore         field  Royal Challengers Bangalore
# 416             Rajasthan Royals           bat             Rajasthan Royals
# 475              Kings XI Punjab         field              Kings XI Punjab
# 485             Rajasthan Royals         field                          NaN
# 511  Royal Challengers Bangalore         field                          NaN
# 610                Gujarat Lions           bat               Mumbai Indians
# 705               Delhi Capitals         field               Delhi Capitals
# 744             Rajasthan Royals         field                          NaN
# 746               Mumbai Indians           bat               Mumbai Indians
# 757              Kings XI Punjab         field               Delhi Capitals
# 765               Mumbai Indians         field  Royal Challengers Bangalore
# 790          Sunrisers Hyderabad         field        Kolkata Knight Riders
# 791               Mumbai Indians           bat              Kings XI Punjab
# 835               Delhi Capitals           bat               Delhi Capitals
# 994          Chennai Super Kings         field                          NaN
#
#         result  result_margin  target_runs  target_overs super_over  \
# 66         tie            NaN        151.0          20.0          Y
# 130        tie            NaN        137.0          20.0          Y
# 241  no result            NaN          NaN           NaN          N
# 328        tie            NaN        131.0          20.0          Y
# 342        tie            NaN        153.0          20.0          Y
# 416        tie            NaN        153.0          20.0          Y
# 475        tie            NaN        192.0          20.0          Y
# 485  no result            NaN          NaN           NaN          N
# 511  no result            NaN        188.0          20.0          N
# 610        tie            NaN        154.0          20.0          Y
# 705        tie            NaN        186.0          20.0          Y
# 744  no result            NaN         63.0           5.0          N
# 746        tie            NaN        163.0          20.0          Y
# 757        tie            NaN        158.0          20.0          Y
# 765        tie            NaN        202.0          20.0          Y
# 790        tie            NaN        164.0          20.0          Y
# 791        tie            NaN        177.0          20.0          Y
# 835        tie            NaN        160.0          20.0          Y
# 994  no result            NaN          NaN           NaN          N
#
#             method          umpire1                umpire2
# 66   Normal method        MR Benson              M Erasmus
# 130  Normal method      K Hariharan              DJ Harper
# 241  Normal method        SS Hazare              RJ Tucker
# 328  Normal method     AK Chaudhary                 S Ravi
# 342  Normal method        M Erasmus            VA Kulkarni
# 416  Normal method        Aleem Dar           AK Chaudhary
# 475  Normal method        M Erasmus                 S Ravi
# 485  Normal method        JD Cloete              PG Pathak
# 511  Normal method  HDPK Dharmasena           K Srinivasan
# 610  Normal method     AK Chaudhary            CB Gaffaney
# 705  Normal method      AY Dandekar            Nitin Menon
# 744  Normal method         NJ Llong              UV Gandhe
# 746  Normal method        CK Nandan                 S Ravi
# 757  Normal method     AK Chaudhary            Nitin Menon
# 765  Normal method      Nitin Menon             PR Reiffel
# 790  Normal method        PG Pathak                 S Ravi
# 791  Normal method      Nitin Menon             PR Reiffel
# 835  Normal method      CB Gaffaney  KN Ananthapadmanabhan
# 994  Normal method     AK Chaudhary          NA Patwardhan

# %%
df_matches['result_margin'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 1095 entries, 0 to 1094
# Series name: result_margin
# Non-Null Count  Dtype
# --------------  -----
# 1076 non-null   float64
# dtypes: float64(1)
# memory usage: 8.7 KB

# %%
df_matches['result_margin'].fillna(0, inplace = True)
print('done')
# Out:
# done
# /var/folders/y0/tq9y6qys5zx8m8_x74cgbd040000gn/T/ipykernel_51351/3158733585.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_matches['result_margin'].fillna(0, inplace = True)

# %%
# Columns with Missing values
# winner, player_of_match, target_overs,target_runs

# %%
df_matches[df_matches['winner'].isna()]
# Out:
#           id season       city        date match_type player_of_match  \
# 241   501265   2011      Delhi  2011-05-21     League             NaN
# 485   829763   2015  Bangalore  2015-04-29     League             NaN
# 511   829813   2015  Bangalore  2015-05-17     League             NaN
# 744  1178424   2019  Bengaluru  2019-04-30     League             NaN
# 994  1359519   2023    Lucknow  2023-05-03     League             NaN
#
#                                                  venue  \
# 241                                   Feroz Shah Kotla
# 485                              M Chinnaswamy Stadium
# 511                              M Chinnaswamy Stadium
# 744                              M.Chinnaswamy Stadium
# 994  Bharat Ratna Shri Atal Bihari Vajpayee Ekana C...
#
#                            team1                team2  \
# 241             Delhi Daredevils        Pune Warriors
# 485  Royal Challengers Bangalore     Rajasthan Royals
# 511  Royal Challengers Bangalore     Delhi Daredevils
# 744  Royal Challengers Bangalore     Rajasthan Royals
# 994         Lucknow Super Giants  Chennai Super Kings
#
#                      toss_winner toss_decision winner     result  \
# 241             Delhi Daredevils           bat    NaN  no result
# 485             Rajasthan Royals         field    NaN  no result
# 511  Royal Challengers Bangalore         field    NaN  no result
# 744             Rajasthan Royals         field    NaN  no result
# 994          Chennai Super Kings         field    NaN  no result
#
#      result_margin  target_runs  target_overs super_over         method  \
# 241            0.0          NaN           NaN          N  Normal method
# 485            0.0          NaN           NaN          N  Normal method
# 511            0.0        188.0          20.0          N  Normal method
# 744            0.0         63.0           5.0          N  Normal method
# 994            0.0          NaN           NaN          N  Normal method
#
#              umpire1        umpire2
# 241        SS Hazare      RJ Tucker
# 485        JD Cloete      PG Pathak
# 511  HDPK Dharmasena   K Srinivasan
# 744         NJ Llong      UV Gandhe
# 994     AK Chaudhary  NA Patwardhan

# %%
df_matches.fillna({'player_of_match': 'No Player of the match',
                   'winner':'No Winner'}, inplace = True)
print('done')
# Out:
# done

# %%
df_matches.fillna(0,inplace = True)
print('Done')
# Out:
# Done

# %%
df_matches.isna().sum()
# Out:
# id                 0
# season             0
# city               0
# date               0
# match_type         0
# player_of_match    0
# venue              0
# team1              0
# team2              0
# toss_winner        0
# toss_decision      0
# winner             0
# result             0
# result_margin      0
# target_runs        0
# target_overs       0
# super_over         0
# method             0
# umpire1            0
# umpire2            0
# dtype: int64

# %%
sns.heatmap(df_matches.isna())
# Out:
# <Axes: >

# %%
# replace

# %%
df_matches['city'].value_counts()
# Out:
# city
# Mumbai            173
# Kolkata            93
# Delhi              90
# Chennai            85
# Hyderabad          77
# Bangalore          65
# Chandigarh         61
# Jaipur             57
# UAE                51
# Pune               51
# Abu Dhabi          37
# Ahmedabad          36
# Bengaluru          29
# Durban             15
# Visakhapatnam      15
# Lucknow            14
# Dharamsala         13
# Dubai              13
# Centurion          12
# Rajkot             10
# Sharjah            10
# Indore              9
# Navi Mumbai         9
# Johannesburg        8
# Cuttack             7
# Ranchi              7
# Port Elizabeth      7
# Cape Town           7
# Raipur              6
# Mohali              5
# Kochi               5
# Kanpur              4
# Kimberley           3
# East London         3
# Guwahati            3
# Nagpur              3
# Bloemfontein        2
# Name: count, dtype: int64

# %%
data_rp = {'Navi Mumbai':'Mumbai',
          'Bengaluru':'Bangalore',
          'Sharjah':'UAE',
           'Abu Dhabi':'UAE',
           'Kimberley':'Cape Town',
           'Dubai':'UAE'
          }

df_matches.replace(data_rp,inplace = True)
print('done')
# Out:
# done

# %%
# check Duplicates

# %%
df_matches.duplicated('id').value_counts()
# Out:
# False    1095
# Name: count, dtype: int64

# %%
df_matches.drop_duplicates('id',inplace = True)
print('Done')
# Out:
# Done

# %%
df_matches.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1095 entries, 0 to 1094
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               1095 non-null   int64
#  1   season           1095 non-null   object
#  2   city             1095 non-null   object
#  3   date             1095 non-null   object
#  4   match_type       1095 non-null   object
#  5   player_of_match  1095 non-null   object
#  6   venue            1095 non-null   object
#  7   team1            1095 non-null   object
#  8   team2            1095 non-null   object
#  9   toss_winner      1095 non-null   object
#  10  toss_decision    1095 non-null   object
#  11  winner           1095 non-null   object
#  12  result           1095 non-null   object
#  13  result_margin    1095 non-null   float64
#  14  target_runs      1095 non-null   float64
#  15  target_overs     1095 non-null   float64
#  16  super_over       1095 non-null   object
#  17  method           1095 non-null   object
#  18  umpire1          1095 non-null   object
#  19  umpire2          1095 non-null   object
# dtypes: float64(3), int64(1), object(16)
# memory usage: 171.2+ KB

# %%
# Date column must be in date datatype

# %%
df_matches['date'] = pd.to_datetime(df_matches['date'])
print('Done')
# Out:
# Done

# %%
df_matches.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1095 entries, 0 to 1094
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               1095 non-null   int64
#  1   season           1095 non-null   object
#  2   city             1095 non-null   object
#  3   date             1095 non-null   datetime64[ns]
#  4   match_type       1095 non-null   object
#  5   player_of_match  1095 non-null   object
#  6   venue            1095 non-null   object
#  7   team1            1095 non-null   object
#  8   team2            1095 non-null   object
#  9   toss_winner      1095 non-null   object
#  10  toss_decision    1095 non-null   object
#  11  winner           1095 non-null   object
#  12  result           1095 non-null   object
#  13  result_margin    1095 non-null   float64
#  14  target_runs      1095 non-null   float64
#  15  target_overs     1095 non-null   float64
#  16  super_over       1095 non-null   object
#  17  method           1095 non-null   object
#  18  umpire1          1095 non-null   object
#  19  umpire2          1095 non-null   object
# dtypes: datetime64[ns](1), float64(3), int64(1), object(15)
# memory usage: 171.2+ KB

# %%
df_matches['venue'].value_counts()
# Out:
# venue
# Eden Gardens                                                             77
# Wankhede Stadium                                                         73
# M Chinnaswamy Stadium                                                    65
# Feroz Shah Kotla                                                         60
# Rajiv Gandhi International Stadium, Uppal                                49
# MA Chidambaram Stadium, Chepauk                                          48
# Sawai Mansingh Stadium                                                   47
# Dubai International Cricket Stadium                                      46
# Wankhede Stadium, Mumbai                                                 45
# Punjab Cricket Association Stadium, Mohali                               35
# Sheikh Zayed Stadium                                                     29
# Sharjah Cricket Stadium                                                  28
# MA Chidambaram Stadium, Chepauk, Chennai                                 28
# Narendra Modi Stadium, Ahmedabad                                         24
# Maharashtra Cricket Association Stadium                                  22
# Dr DY Patil Sports Academy, Mumbai                                       20
# Brabourne Stadium, Mumbai                                                17
# Dr DY Patil Sports Academy                                               17
# Eden Gardens, Kolkata                                                    16
# Subrata Roy Sahara Stadium                                               16
# Arun Jaitley Stadium, Delhi                                              16
# Rajiv Gandhi International Stadium                                       15
# M.Chinnaswamy Stadium                                                    15
# Kingsmead                                                                15
# Arun Jaitley Stadium                                                     14
# Bharat Ratna Shri Atal Bihari Vajpayee Ekana Cricket Stadium, Lucknow    14
# M Chinnaswamy Stadium, Bengaluru                                         14
# Rajiv Gandhi International Stadium, Uppal, Hyderabad                     13
# Maharashtra Cricket Association Stadium, Pune                            13
# Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Stadium                      13
# SuperSport Park                                                          12
# Sardar Patel Stadium, Motera                                             12
# Punjab Cricket Association IS Bindra Stadium, Mohali                     11
# Sawai Mansingh Stadium, Jaipur                                           10
# Saurashtra Cricket Association Stadium                                   10
# Brabourne Stadium                                                        10
# Punjab Cricket Association IS Bindra Stadium                             10
# Himachal Pradesh Cricket Association Stadium                              9
# MA Chidambaram Stadium                                                    9
# Holkar Cricket Stadium                                                    9
# New Wanderers Stadium                                                     8
# Zayed Cricket Stadium, Abu Dhabi                                          8
# JSCA International Stadium Complex                                        7
# Barabati Stadium                                                          7
# St George's Park                                                          7
# Newlands                                                                  7
# Shaheed Veer Narayan Singh International Stadium                          6
# Nehru Stadium                                                             5
# Punjab Cricket Association IS Bindra Stadium, Mohali, Chandigarh          5
# Maharaja Yadavindra Singh International Cricket Stadium, Mullanpur        5
# Green Park                                                                4
# Himachal Pradesh Cricket Association Stadium, Dharamsala                  4
# Vidarbha Cricket Association Stadium, Jamtha                              3
# De Beers Diamond Oval                                                     3
# Buffalo Park                                                              3
# Barsapara Cricket Stadium, Guwahati                                       3
# OUTsurance Oval                                                           2
# Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Stadium, Visakhapatnam        2
# Name: count, dtype: int64

# %%
df_matches['venue'].str.split(',')
# Out:
# 0                                 [M Chinnaswamy Stadium]
# 1           [Punjab Cricket Association Stadium,  Mohali]
# 2                                      [Feroz Shah Kotla]
# 3                                      [Wankhede Stadium]
# 4                                          [Eden Gardens]
#                               ...
# 1090    [Rajiv Gandhi International Stadium,  Uppal,  ...
# 1091                  [Narendra Modi Stadium,  Ahmedabad]
# 1092                  [Narendra Modi Stadium,  Ahmedabad]
# 1093         [MA Chidambaram Stadium,  Chepauk,  Chennai]
# 1094         [MA Chidambaram Stadium,  Chepauk,  Chennai]
# Name: venue, Length: 1095, dtype: object

# %%
df_matches['venue'] = df_matches['venue'].apply(lambda row: row.title().split(',')[0]) #apply() :row wise method or function runs
print('done')
# Out:
# done

# %%
df_matches['venue'].value_counts()
# Out:
# venue
# Wankhede Stadium                                                118
# Eden Gardens                                                     93
# Ma Chidambaram Stadium                                           85
# M Chinnaswamy Stadium                                            79
# Rajiv Gandhi International Stadium                               77
# Feroz Shah Kotla                                                 60
# Sawai Mansingh Stadium                                           57
# Dubai International Cricket Stadium                              46
# Dr Dy Patil Sports Academy                                       37
# Maharashtra Cricket Association Stadium                          35
# Punjab Cricket Association Stadium                               35
# Arun Jaitley Stadium                                             30
# Sheikh Zayed Stadium                                             29
# Sharjah Cricket Stadium                                          28
# Brabourne Stadium                                                27
# Punjab Cricket Association Is Bindra Stadium                     26
# Narendra Modi Stadium                                            24
# Subrata Roy Sahara Stadium                                       16
# Dr. Y.S. Rajasekhara Reddy Aca-Vdca Cricket Stadium              15
# M.Chinnaswamy Stadium                                            15
# Kingsmead                                                        15
# Bharat Ratna Shri Atal Bihari Vajpayee Ekana Cricket Stadium     14
# Himachal Pradesh Cricket Association Stadium                     13
# Sardar Patel Stadium                                             12
# Supersport Park                                                  12
# Saurashtra Cricket Association Stadium                           10
# Holkar Cricket Stadium                                            9
# Zayed Cricket Stadium                                             8
# New Wanderers Stadium                                             8
# Jsca International Stadium Complex                                7
# Barabati Stadium                                                  7
# St George'S Park                                                  7
# Newlands                                                          7
# Shaheed Veer Narayan Singh International Stadium                  6
# Nehru Stadium                                                     5
# Maharaja Yadavindra Singh International Cricket Stadium           5
# Green Park                                                        4
# De Beers Diamond Oval                                             3
# Buffalo Park                                                      3
# Vidarbha Cricket Association Stadium                              3
# Barsapara Cricket Stadium                                         3
# Outsurance Oval                                                   2
# Name: count, dtype: int64

# %%
data_v_rp = {'M.Chinnaswamy Stadium':'M Chinnaswamy Stadium',
             'Feroz Shah Kotla':'Arun Jaitley Stadium',
             'Sardar Patel Stadium':'Narendra Modi Stadium',
             'Punjab Cricket Association Is Bindra Stadium':'Punjab Cricket Association Stadium' }

df_matches['venue'].replace(data_v_rp,inplace = True)
print('Done')
# Out:
# Done
# /var/folders/y0/tq9y6qys5zx8m8_x74cgbd040000gn/T/ipykernel_51351/2614453559.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_matches['venue'].replace(data_v_rp,inplace = True)

# %%
x = df_matches['venue'].value_counts().head(10).index
y = df_matches['venue'].value_counts().head(10).values

plt.figure(figsize=(7,5))
ax = plt.barh(x,y,color = sns.color_palette('rainbow',10))
plt.bar_label(ax)
plt.title("Top 10 venue by matches played")
plt.xticks(rotation = 90)
plt.show()

# %%
df_matches['team1'].value_counts()
# Out:
# team1
# Royal Challengers Bangalore    135
# Chennai Super Kings            128
# Mumbai Indians                 123
# Kolkata Knight Riders          121
# Rajasthan Royals               101
# Kings XI Punjab                 92
# Sunrisers Hyderabad             86
# Delhi Daredevils                85
# Delhi Capitals                  41
# Deccan Chargers                 39
# Punjab Kings                    31
# Lucknow Super Giants            23
# Pune Warriors                   23
# Gujarat Titans                  21
# Gujarat Lions                   16
# Royal Challengers Bengaluru      9
# Rising Pune Supergiant           7
# Rising Pune Supergiants          7
# Kochi Tuskers Kerala             7
# Name: count, dtype: int64

# %%
df_matches['team2'].value_counts()
# Out:
# team2
# Mumbai Indians                 138
# Kolkata Knight Riders          130
# Rajasthan Royals               120
# Chennai Super Kings            110
# Royal Challengers Bangalore    105
# Kings XI Punjab                 98
# Sunrisers Hyderabad             96
# Delhi Daredevils                76
# Delhi Capitals                  50
# Deccan Chargers                 36
# Punjab Kings                    25
# Gujarat Titans                  24
# Pune Warriors                   23
# Lucknow Super Giants            21
# Gujarat Lions                   14
# Rising Pune Supergiant           9
# Rising Pune Supergiants          7
# Kochi Tuskers Kerala             7
# Royal Challengers Bengaluru      6
# Name: count, dtype: int64

# %%
import warnings
warnings.filterwarnings('ignore')

team_name_rp = { 'Royal Challengers Bangalore':'Royal Challengers Bengaluru',
                'Delhi Daredevils':'Delhi Capitals',
                'Kings XI Punjab':'Punjab Kings',
                'Rising Pune Supergiant':'Rising Pune Supergiants',
                'Pune Warriors':'Rising Pune Supergiants'}
df_matches[['team1','team2']]= df_matches[['team1','team2']].replace(team_name_rp)
print('Done')
# Out:
# Done

# %%
df_matches
# Out:
#            id   season        city       date   match_type  player_of_match  \
# 0      335982  2007/08   Bangalore 2008-04-18       League      BB McCullum
# 1      335983  2007/08  Chandigarh 2008-04-19       League       MEK Hussey
# 2      335984  2007/08       Delhi 2008-04-19       League      MF Maharoof
# 3      335985  2007/08      Mumbai 2008-04-20       League       MV Boucher
# 4      335986  2007/08     Kolkata 2008-04-20       League        DJ Hussey
# ...       ...      ...         ...        ...          ...              ...
# 1090  1426307     2024   Hyderabad 2024-05-19       League  Abhishek Sharma
# 1091  1426309     2024   Ahmedabad 2024-05-21  Qualifier 1         MA Starc
# 1092  1426310     2024   Ahmedabad 2024-05-22   Eliminator         R Ashwin
# 1093  1426311     2024     Chennai 2024-05-24  Qualifier 2    Shahbaz Ahmed
# 1094  1426312     2024     Chennai 2024-05-26        Final         MA Starc
#
#                                    venue                        team1  \
# 0                  M Chinnaswamy Stadium  Royal Challengers Bengaluru
# 1     Punjab Cricket Association Stadium                 Punjab Kings
# 2                   Arun Jaitley Stadium               Delhi Capitals
# 3                       Wankhede Stadium               Mumbai Indians
# 4                           Eden Gardens        Kolkata Knight Riders
# ...                                  ...                          ...
# 1090  Rajiv Gandhi International Stadium                 Punjab Kings
# 1091               Narendra Modi Stadium          Sunrisers Hyderabad
# 1092               Narendra Modi Stadium  Royal Challengers Bengaluru
# 1093              Ma Chidambaram Stadium          Sunrisers Hyderabad
# 1094              Ma Chidambaram Stadium          Sunrisers Hyderabad
#
#                             team2                  toss_winner toss_decision  \
# 0           Kolkata Knight Riders  Royal Challengers Bangalore         field
# 1             Chennai Super Kings          Chennai Super Kings           bat
# 2                Rajasthan Royals             Rajasthan Royals           bat
# 3     Royal Challengers Bengaluru               Mumbai Indians           bat
# 4                 Deccan Chargers              Deccan Chargers           bat
# ...                           ...                          ...           ...
# 1090          Sunrisers Hyderabad                 Punjab Kings           bat
# 1091        Kolkata Knight Riders          Sunrisers Hyderabad           bat
# 1092             Rajasthan Royals             Rajasthan Royals         field
# 1093             Rajasthan Royals             Rajasthan Royals         field
# 1094        Kolkata Knight Riders          Sunrisers Hyderabad           bat
#
#                            winner   result  result_margin  target_runs  \
# 0           Kolkata Knight Riders     runs          140.0        223.0
# 1             Chennai Super Kings     runs           33.0        241.0
# 2                Delhi Daredevils  wickets            9.0        130.0
# 3     Royal Challengers Bangalore  wickets            5.0        166.0
# 4           Kolkata Knight Riders  wickets            5.0        111.0
# ...                           ...      ...            ...          ...
# 1090          Sunrisers Hyderabad  wickets            4.0        215.0
# 1091        Kolkata Knight Riders  wickets            8.0        160.0
# 1092             Rajasthan Royals  wickets            4.0        173.0
# 1093          Sunrisers Hyderabad     runs           36.0        176.0
# 1094        Kolkata Knight Riders  wickets            8.0        114.0
#
#       target_overs super_over         method                umpire1  \
# 0             20.0          N  Normal method              Asad Rauf
# 1             20.0          N  Normal method              MR Benson
# 2             20.0          N  Normal method              Aleem Dar
# 3             20.0          N  Normal method               SJ Davis
# 4             20.0          N  Normal method              BF Bowden
# ...            ...        ...            ...                    ...
# 1090          20.0          N  Normal method            Nitin Menon
# 1091          20.0          N  Normal method           AK Chaudhary
# 1092          20.0          N  Normal method  KN Ananthapadmanabhan
# 1093          20.0          N  Normal method            Nitin Menon
# 1094          20.0          N  Normal method          J Madanagopal
#
#                    umpire2
# 0              RE Koertzen
# 1               SL Shastri
# 2           GA Pratapkumar
# 3                DJ Harper
# 4              K Hariharan
# ...                    ...
# 1090             VK Sharma
# 1091              R Pandit
# 1092  MV Saidharshan Kumar
# 1093             VK Sharma
# 1094           Nitin Menon
#
# [1095 rows x 20 columns]

# %%
team_name_rp = { 'Royal Challengers Bangalore':'Royal Challengers Bengaluru',
                'Delhi Daredevils':'Delhi Capitals',
                'Kings XI Punjab':'Punjab Kings',
                'Rising Pune Supergiant':'Rising Pune Supergiants',
                'Pune Warriors':'Rising Pune Supergiants'}
df_matches['toss_winner'].replace(team_name_rp,inplace = True)
df_matches['winner'].replace(team_name_rp,inplace = True)

print('Done')
# Out:
# Done

# %%
#  umpire1 and umpire2

# %%
df_matches['umpire1'].value_counts()
# Out:
# umpire1
# AK Chaudhary             115
# HDPK Dharmasena           79
# KN Ananthapadmanabhan     59
# CB Gaffaney               53
# Asad Rauf                 51
#                         ...
# AV Jayaprakash             2
# K Srinath                  2
# AG Wharf                   2
# SL Shastri                 1
# SJA Taufel                 1
# Name: count, Length: 62, dtype: int64

# %%
# Drop #umpire1 and umpire2

# %%
df_matches.drop(['umpire1','umpire2'],axis =1,inplace =True)
print('Done')
# Out:
# Done

# %%
df_matches.sample(10)
# Out:
#            id season       city       date match_type player_of_match  \
# 957   1359482   2023   Guwahati 2023-04-05     League        NT Ellis
# 539    980945   2016      Delhi 2016-04-27     League       CH Morris
# 677   1136602   2018      Delhi 2018-05-10     League        S Dhawan
# 597   1082611   2017  Hyderabad 2017-04-19     League   KS Williamson
# 1061  1426276   2024     Jaipur 2024-04-22     League  Sandeep Sharma
# 381    598057   2013     Ranchi 2013-05-12     League       JH Kallis
# 645   1136570   2018    Kolkata 2018-04-14     League      B Stanlake
# 521    980909   2016    Kolkata 2016-04-13     League       RG Sharma
# 705   1175365   2019      Delhi 2019-03-30     League         PP Shaw
# 458    829705   2015    Kolkata 2015-04-08     League        M Morkel
#
#                                    venue                  team1  \
# 957            Barsapara Cricket Stadium           Punjab Kings
# 539                 Arun Jaitley Stadium         Delhi Capitals
# 677                 Arun Jaitley Stadium         Delhi Capitals
# 597   Rajiv Gandhi International Stadium    Sunrisers Hyderabad
# 1061              Sawai Mansingh Stadium         Mumbai Indians
# 381   Jsca International Stadium Complex  Kolkata Knight Riders
# 645                         Eden Gardens  Kolkata Knight Riders
# 521                         Eden Gardens  Kolkata Knight Riders
# 705                 Arun Jaitley Stadium  Kolkata Knight Riders
# 458                         Eden Gardens  Kolkata Knight Riders
#
#                             team2            toss_winner toss_decision  \
# 957              Rajasthan Royals       Rajasthan Royals         field
# 539                 Gujarat Lions         Delhi Capitals         field
# 677           Sunrisers Hyderabad         Delhi Capitals           bat
# 597                Delhi Capitals    Sunrisers Hyderabad           bat
# 1061             Rajasthan Royals         Mumbai Indians           bat
# 381   Royal Challengers Bengaluru  Kolkata Knight Riders         field
# 645           Sunrisers Hyderabad    Sunrisers Hyderabad         field
# 521                Mumbai Indians         Mumbai Indians         field
# 705                Delhi Capitals         Delhi Capitals         field
# 458                Mumbai Indians  Kolkata Knight Riders         field
#
#                      winner   result  result_margin  target_runs  \
# 957            Punjab Kings     runs            5.0        198.0
# 539           Gujarat Lions     runs            1.0        173.0
# 677     Sunrisers Hyderabad  wickets            9.0        188.0
# 597     Sunrisers Hyderabad     runs           15.0        192.0
# 1061       Rajasthan Royals  wickets            9.0        180.0
# 381   Kolkata Knight Riders  wickets            5.0        116.0
# 645     Sunrisers Hyderabad  wickets            5.0        139.0
# 521          Mumbai Indians  wickets            6.0        188.0
# 705          Delhi Capitals      tie            0.0        186.0
# 458   Kolkata Knight Riders  wickets            7.0        169.0
#
#       target_overs super_over         method
# 957           20.0          N  Normal method
# 539           20.0          N  Normal method
# 677           20.0          N  Normal method
# 597           20.0          N  Normal method
# 1061          20.0          N  Normal method
# 381           20.0          N  Normal method
# 645           20.0          N  Normal method
# 521           20.0          N  Normal method
# 705           20.0          Y  Normal method
# 458           20.0          N  Normal method

# %%
df_matches.columns
# Out:
# Index(['id', 'season', 'city', 'date', 'match_type', 'player_of_match',
#        'venue', 'team1', 'team2', 'toss_winner', 'toss_decision', 'winner',
#        'result', 'result_margin', 'target_runs', 'target_overs', 'super_over',
#        'method'],
#       dtype='object')

# %%
df_matches.shape
# Out:
# (1095, 18)

# %%
df_matches['winner'].value_counts()
# Out:
# winner
# Mumbai Indians                 144
# Chennai Super Kings            138
# Kolkata Knight Riders          131
# Royal Challengers Bengaluru    123
# Delhi Capitals                 115
# Rajasthan Royals               112
# Punjab Kings                   112
# Sunrisers Hyderabad             88
# Deccan Chargers                 29
# Gujarat Titans                  28
# Rising Pune Supergiants         27
# Lucknow Super Giants            24
# Gujarat Lions                   13
# Kochi Tuskers Kerala             6
# No Winner                        5
# Name: count, dtype: int64

# %%
df_matches['match_type'].value_counts()
# Out:
# match_type
# League                1029
# Final                   17
# Qualifier 1             14
# Qualifier 2             14
# Eliminator              11
# Semi Final               6
# Elimination Final        3
# 3rd Place Play-Off       1
# Name: count, dtype: int64

# %%
# List Ipl winner 
df_matches[df_matches['match_type'] == 'Final']['winner'].value_counts()
# Out:
# winner
# Chennai Super Kings      5
# Mumbai Indians           5
# Kolkata Knight Riders    3
# Rajasthan Royals         1
# Deccan Chargers          1
# Sunrisers Hyderabad      1
# Gujarat Titans           1
# Name: count, dtype: int64

# %%
plt.title("IPL Winner")
df_matches[df_matches['match_type'] == 'Final']['winner'].value_counts().plot(kind = 'pie', autopct = '%.2f%%')
plt.show()

# %%
df_matches['date'].dt.year
# Out:
# 0       2008
# 1       2008
# 2       2008
# 3       2008
# 4       2008
#         ...
# 1090    2024
# 1091    2024
# 1092    2024
# 1093    2024
# 1094    2024
# Name: date, Length: 1095, dtype: int32

# %%
Final_matche = df_matches[df_matches['match_type'] == 'Final']
Final_matche
# Out:
#            id   season          city       date match_type player_of_match  \
# 57     336040  2007/08        Mumbai 2008-06-01      Final       YK Pathan
# 114    392239     2009  Johannesburg 2009-05-24      Final        A Kumble
# 174    419165  2009/10        Mumbai 2010-04-25      Final        SK Raina
# 247    501271     2011       Chennai 2011-05-28      Final         M Vijay
# 321    548381     2012       Chennai 2012-05-27      Final        MS Bisla
# 397    598073     2013       Kolkata 2013-05-26      Final      KA Pollard
# 457    734049     2014     Bangalore 2014-06-01      Final       MK Pandey
# 516    829823     2015       Kolkata 2015-05-24      Final       RG Sharma
# 576    981019     2016     Bangalore 2016-05-29      Final     BCJ Cutting
# 635   1082650     2017     Hyderabad 2017-05-21      Final       KH Pandya
# 695   1136620     2018        Mumbai 2018-05-27      Final       SR Watson
# 755   1181768     2019     Hyderabad 2019-05-12      Final       JJ Bumrah
# 815   1237181  2020/21           UAE 2020-11-10      Final        TA Boult
# 875   1254117     2021           UAE 2021-10-15      Final    F du Plessis
# 949   1312200     2022     Ahmedabad 2022-05-29      Final       HH Pandya
# 1023  1370353     2023     Ahmedabad 2023-05-29      Final       DP Conway
# 1094  1426312     2024       Chennai 2024-05-26      Final        MA Starc
#
#                                     venue                        team1  \
# 57             Dr Dy Patil Sports Academy          Chennai Super Kings
# 114                 New Wanderers Stadium  Royal Challengers Bengaluru
# 174            Dr Dy Patil Sports Academy          Chennai Super Kings
# 247                Ma Chidambaram Stadium          Chennai Super Kings
# 321                Ma Chidambaram Stadium        Kolkata Knight Riders
# 397                          Eden Gardens          Chennai Super Kings
# 457                 M Chinnaswamy Stadium        Kolkata Knight Riders
# 516                          Eden Gardens               Mumbai Indians
# 576                 M Chinnaswamy Stadium  Royal Challengers Bengaluru
# 635    Rajiv Gandhi International Stadium               Mumbai Indians
# 695                      Wankhede Stadium          Sunrisers Hyderabad
# 755    Rajiv Gandhi International Stadium               Mumbai Indians
# 815   Dubai International Cricket Stadium               Delhi Capitals
# 875   Dubai International Cricket Stadium          Chennai Super Kings
# 949                 Narendra Modi Stadium             Rajasthan Royals
# 1023                Narendra Modi Stadium               Gujarat Titans
# 1094               Ma Chidambaram Stadium          Sunrisers Hyderabad
#
#                             team2                  toss_winner toss_decision  \
# 57               Rajasthan Royals             Rajasthan Royals         field
# 114               Deccan Chargers  Royal Challengers Bengaluru         field
# 174                Mumbai Indians          Chennai Super Kings           bat
# 247   Royal Challengers Bengaluru          Chennai Super Kings           bat
# 321           Chennai Super Kings          Chennai Super Kings           bat
# 397                Mumbai Indians               Mumbai Indians           bat
# 457                  Punjab Kings        Kolkata Knight Riders         field
# 516           Chennai Super Kings          Chennai Super Kings         field
# 576           Sunrisers Hyderabad          Sunrisers Hyderabad           bat
# 635       Rising Pune Supergiants               Mumbai Indians           bat
# 695           Chennai Super Kings          Chennai Super Kings         field
# 755           Chennai Super Kings               Mumbai Indians           bat
# 815                Mumbai Indians               Delhi Capitals           bat
# 875         Kolkata Knight Riders        Kolkata Knight Riders         field
# 949                Gujarat Titans             Rajasthan Royals           bat
# 1023          Chennai Super Kings          Chennai Super Kings         field
# 1094        Kolkata Knight Riders          Sunrisers Hyderabad           bat
#
#                      winner   result  result_margin  target_runs  \
# 57         Rajasthan Royals  wickets            3.0        164.0
# 114         Deccan Chargers     runs            6.0        144.0
# 174     Chennai Super Kings     runs           22.0        169.0
# 247     Chennai Super Kings     runs           58.0        206.0
# 321   Kolkata Knight Riders  wickets            5.0        191.0
# 397          Mumbai Indians     runs           23.0        149.0
# 457   Kolkata Knight Riders  wickets            3.0        200.0
# 516          Mumbai Indians     runs           41.0        203.0
# 576     Sunrisers Hyderabad     runs            8.0        209.0
# 635          Mumbai Indians     runs            1.0        130.0
# 695     Chennai Super Kings  wickets            8.0        179.0
# 755          Mumbai Indians     runs            1.0        150.0
# 815          Mumbai Indians  wickets            5.0        157.0
# 875     Chennai Super Kings     runs           27.0        193.0
# 949          Gujarat Titans  wickets            7.0        131.0
# 1023    Chennai Super Kings  wickets            5.0        171.0
# 1094  Kolkata Knight Riders  wickets            8.0        114.0
#
#       target_overs super_over         method
# 57            20.0          N  Normal method
# 114           20.0          N  Normal method
# 174           20.0          N  Normal method
# 247           20.0          N  Normal method
# 321           20.0          N  Normal method
# 397           20.0          N  Normal method
# 457           20.0          N  Normal method
# 516           20.0          N  Normal method
# 576           20.0          N  Normal method
# 635           20.0          N  Normal method
# 695           20.0          N  Normal method
# 755           20.0          N  Normal method
# 815           20.0          N  Normal method
# 875           20.0          N  Normal method
# 949           20.0          N  Normal method
# 1023          15.0          N            D/L
# 1094          20.0          N  Normal method

# %%
Final_matche['Winning year'] = Final_matche['date'].dt.year
print('Done')
# Out:
# Done

# %%
Final_matche
# Out:
#            id   season          city       date match_type player_of_match  \
# 57     336040  2007/08        Mumbai 2008-06-01      Final       YK Pathan
# 114    392239     2009  Johannesburg 2009-05-24      Final        A Kumble
# 174    419165  2009/10        Mumbai 2010-04-25      Final        SK Raina
# 247    501271     2011       Chennai 2011-05-28      Final         M Vijay
# 321    548381     2012       Chennai 2012-05-27      Final        MS Bisla
# 397    598073     2013       Kolkata 2013-05-26      Final      KA Pollard
# 457    734049     2014     Bangalore 2014-06-01      Final       MK Pandey
# 516    829823     2015       Kolkata 2015-05-24      Final       RG Sharma
# 576    981019     2016     Bangalore 2016-05-29      Final     BCJ Cutting
# 635   1082650     2017     Hyderabad 2017-05-21      Final       KH Pandya
# 695   1136620     2018        Mumbai 2018-05-27      Final       SR Watson
# 755   1181768     2019     Hyderabad 2019-05-12      Final       JJ Bumrah
# 815   1237181  2020/21           UAE 2020-11-10      Final        TA Boult
# 875   1254117     2021           UAE 2021-10-15      Final    F du Plessis
# 949   1312200     2022     Ahmedabad 2022-05-29      Final       HH Pandya
# 1023  1370353     2023     Ahmedabad 2023-05-29      Final       DP Conway
# 1094  1426312     2024       Chennai 2024-05-26      Final        MA Starc
#
#                                     venue                        team1  \
# 57             Dr Dy Patil Sports Academy          Chennai Super Kings
# 114                 New Wanderers Stadium  Royal Challengers Bengaluru
# 174            Dr Dy Patil Sports Academy          Chennai Super Kings
# 247                Ma Chidambaram Stadium          Chennai Super Kings
# 321                Ma Chidambaram Stadium        Kolkata Knight Riders
# 397                          Eden Gardens          Chennai Super Kings
# 457                 M Chinnaswamy Stadium        Kolkata Knight Riders
# 516                          Eden Gardens               Mumbai Indians
# 576                 M Chinnaswamy Stadium  Royal Challengers Bengaluru
# 635    Rajiv Gandhi International Stadium               Mumbai Indians
# 695                      Wankhede Stadium          Sunrisers Hyderabad
# 755    Rajiv Gandhi International Stadium               Mumbai Indians
# 815   Dubai International Cricket Stadium               Delhi Capitals
# 875   Dubai International Cricket Stadium          Chennai Super Kings
# 949                 Narendra Modi Stadium             Rajasthan Royals
# 1023                Narendra Modi Stadium               Gujarat Titans
# 1094               Ma Chidambaram Stadium          Sunrisers Hyderabad
#
#                             team2                  toss_winner toss_decision  \
# 57               Rajasthan Royals             Rajasthan Royals         field
# 114               Deccan Chargers  Royal Challengers Bengaluru         field
# 174                Mumbai Indians          Chennai Super Kings           bat
# 247   Royal Challengers Bengaluru          Chennai Super Kings           bat
# 321           Chennai Super Kings          Chennai Super Kings           bat
# 397                Mumbai Indians               Mumbai Indians           bat
# 457                  Punjab Kings        Kolkata Knight Riders         field
# 516           Chennai Super Kings          Chennai Super Kings         field
# 576           Sunrisers Hyderabad          Sunrisers Hyderabad           bat
# 635       Rising Pune Supergiants               Mumbai Indians           bat
# 695           Chennai Super Kings          Chennai Super Kings         field
# 755           Chennai Super Kings               Mumbai Indians           bat
# 815                Mumbai Indians               Delhi Capitals           bat
# 875         Kolkata Knight Riders        Kolkata Knight Riders         field
# 949                Gujarat Titans             Rajasthan Royals           bat
# 1023          Chennai Super Kings          Chennai Super Kings         field
# 1094        Kolkata Knight Riders          Sunrisers Hyderabad           bat
#
#                      winner   result  result_margin  target_runs  \
# 57         Rajasthan Royals  wickets            3.0        164.0
# 114         Deccan Chargers     runs            6.0        144.0
# 174     Chennai Super Kings     runs           22.0        169.0
# 247     Chennai Super Kings     runs           58.0        206.0
# 321   Kolkata Knight Riders  wickets            5.0        191.0
# 397          Mumbai Indians     runs           23.0        149.0
# 457   Kolkata Knight Riders  wickets            3.0        200.0
# 516          Mumbai Indians     runs           41.0        203.0
# 576     Sunrisers Hyderabad     runs            8.0        209.0
# 635          Mumbai Indians     runs            1.0        130.0
# 695     Chennai Super Kings  wickets            8.0        179.0
# 755          Mumbai Indians     runs            1.0        150.0
# 815          Mumbai Indians  wickets            5.0        157.0
# 875     Chennai Super Kings     runs           27.0        193.0
# 949          Gujarat Titans  wickets            7.0        131.0
# 1023    Chennai Super Kings  wickets            5.0        171.0
# 1094  Kolkata Knight Riders  wickets            8.0        114.0
#
#       target_overs super_over         method  Winning year
# 57            20.0          N  Normal method          2008
# 114           20.0          N  Normal method          2009
# 174           20.0          N  Normal method          2010
# 247           20.0          N  Normal method          2011
# 321           20.0          N  Normal method          2012
# 397           20.0          N  Normal method          2013
# 457           20.0          N  Normal method          2014
# 516           20.0          N  Normal method          2015
# 576           20.0          N  Normal method          2016
# 635           20.0          N  Normal method          2017
# 695           20.0          N  Normal method          2018
# 755           20.0          N  Normal method          2019
# 815           20.0          N  Normal method          2020
# 875           20.0          N  Normal method          2021
# 949           20.0          N  Normal method          2022
# 1023          15.0          N            D/L          2023
# 1094          20.0          N  Normal method          2024

# %%
Final_matche[['Winning year','winner' ]].sort_values('winner')
# Out:
#       Winning year                 winner
# 174           2010    Chennai Super Kings
# 247           2011    Chennai Super Kings
# 1023          2023    Chennai Super Kings
# 695           2018    Chennai Super Kings
# 875           2021    Chennai Super Kings
# 114           2009        Deccan Chargers
# 949           2022         Gujarat Titans
# 1094          2024  Kolkata Knight Riders
# 321           2012  Kolkata Knight Riders
# 457           2014  Kolkata Knight Riders
# 397           2013         Mumbai Indians
# 516           2015         Mumbai Indians
# 635           2017         Mumbai Indians
# 755           2019         Mumbai Indians
# 815           2020         Mumbai Indians
# 57            2008       Rajasthan Royals
# 576           2016    Sunrisers Hyderabad

# %%
Final_matche['result'].value_counts()
# Out:
# result
# runs       9
# wickets    8
# Name: count, dtype: int64

# %%
df_matches['result'].value_counts()
# Out:
# result
# wickets      578
# runs         498
# tie           14
# no result      5
# Name: count, dtype: int64

# %%
df_matches.groupby('venue')['result'].value_counts()
# Out:
# venue                  result
# Arun Jaitley Stadium   runs         44
#                        wickets      44
#                        no result     1
#                        tie           1
# Barabati Stadium       runs          4
#                                     ..
# Wankhede Stadium       wickets      64
#                        runs         53
#                        tie           1
# Zayed Cricket Stadium  wickets       5
#                        runs          3
# Name: count, Length: 88, dtype: int64

# %%
Final_matche.groupby('venue')['result'].value_counts().reset_index()
# Out:
#                                   venue   result  count
# 0            Dr Dy Patil Sports Academy     runs      1
# 1            Dr Dy Patil Sports Academy  wickets      1
# 2   Dubai International Cricket Stadium     runs      1
# 3   Dubai International Cricket Stadium  wickets      1
# 4                          Eden Gardens     runs      2
# 5                 M Chinnaswamy Stadium     runs      1
# 6                 M Chinnaswamy Stadium  wickets      1
# 7                Ma Chidambaram Stadium  wickets      2
# 8                Ma Chidambaram Stadium     runs      1
# 9                 Narendra Modi Stadium  wickets      2
# 10                New Wanderers Stadium     runs      1
# 11   Rajiv Gandhi International Stadium     runs      2
# 12                     Wankhede Stadium  wickets      1

# %%
Final_matche.groupby('venue')['result'].value_counts().reset_index().sort_values(by = 'count',ascending = False )
# Out:
#                                   venue   result  count
# 4                          Eden Gardens     runs      2
# 7                Ma Chidambaram Stadium  wickets      2
# 9                 Narendra Modi Stadium  wickets      2
# 11   Rajiv Gandhi International Stadium     runs      2
# 0            Dr Dy Patil Sports Academy     runs      1
# 1            Dr Dy Patil Sports Academy  wickets      1
# 2   Dubai International Cricket Stadium     runs      1
# 3   Dubai International Cricket Stadium  wickets      1
# 5                 M Chinnaswamy Stadium     runs      1
# 6                 M Chinnaswamy Stadium  wickets      1
# 8                Ma Chidambaram Stadium     runs      1
# 10                New Wanderers Stadium     runs      1
# 12                     Wankhede Stadium  wickets      1

# %%
Final_matche.groupby('venue')['result'].value_counts().reset_index().sort_values(by = 'venue')
# Out:
#                                   venue   result  count
# 0            Dr Dy Patil Sports Academy     runs      1
# 1            Dr Dy Patil Sports Academy  wickets      1
# 2   Dubai International Cricket Stadium     runs      1
# 3   Dubai International Cricket Stadium  wickets      1
# 4                          Eden Gardens     runs      2
# 5                 M Chinnaswamy Stadium     runs      1
# 6                 M Chinnaswamy Stadium  wickets      1
# 7                Ma Chidambaram Stadium  wickets      2
# 8                Ma Chidambaram Stadium     runs      1
# 9                 Narendra Modi Stadium  wickets      2
# 10                New Wanderers Stadium     runs      1
# 11   Rajiv Gandhi International Stadium     runs      2
# 12                     Wankhede Stadium  wickets      1

# %%
df_matches.groupby('venue')['result'].value_counts().reset_index().sort_values(by = 'venue')
# Out:
#                     venue     result  count
# 0    Arun Jaitley Stadium       runs     44
# 1    Arun Jaitley Stadium    wickets     44
# 2    Arun Jaitley Stadium  no result      1
# 3    Arun Jaitley Stadium        tie      1
# 4        Barabati Stadium       runs      4
# ..                    ...        ...    ...
# 83       Wankhede Stadium    wickets     64
# 84       Wankhede Stadium       runs     53
# 85       Wankhede Stadium        tie      1
# 86  Zayed Cricket Stadium    wickets      5
# 87  Zayed Cricket Stadium       runs      3
#
# [88 rows x 3 columns]

# %% [markdown]
# # Day 13

# %%
df_matches
# Out:
#            id   season        city       date   match_type  player_of_match  \
# 0      335982  2007/08   Bangalore 2008-04-18       League      BB McCullum
# 1      335983  2007/08  Chandigarh 2008-04-19       League       MEK Hussey
# 2      335984  2007/08       Delhi 2008-04-19       League      MF Maharoof
# 3      335985  2007/08      Mumbai 2008-04-20       League       MV Boucher
# 4      335986  2007/08     Kolkata 2008-04-20       League        DJ Hussey
# ...       ...      ...         ...        ...          ...              ...
# 1090  1426307     2024   Hyderabad 2024-05-19       League  Abhishek Sharma
# 1091  1426309     2024   Ahmedabad 2024-05-21  Qualifier 1         MA Starc
# 1092  1426310     2024   Ahmedabad 2024-05-22   Eliminator         R Ashwin
# 1093  1426311     2024     Chennai 2024-05-24  Qualifier 2    Shahbaz Ahmed
# 1094  1426312     2024     Chennai 2024-05-26        Final         MA Starc
#
#                                    venue                        team1  \
# 0                  M Chinnaswamy Stadium  Royal Challengers Bengaluru
# 1     Punjab Cricket Association Stadium                 Punjab Kings
# 2                   Arun Jaitley Stadium               Delhi Capitals
# 3                       Wankhede Stadium               Mumbai Indians
# 4                           Eden Gardens        Kolkata Knight Riders
# ...                                  ...                          ...
# 1090  Rajiv Gandhi International Stadium                 Punjab Kings
# 1091               Narendra Modi Stadium          Sunrisers Hyderabad
# 1092               Narendra Modi Stadium  Royal Challengers Bengaluru
# 1093              Ma Chidambaram Stadium          Sunrisers Hyderabad
# 1094              Ma Chidambaram Stadium          Sunrisers Hyderabad
#
#                             team2                  toss_winner toss_decision  \
# 0           Kolkata Knight Riders  Royal Challengers Bengaluru         field
# 1             Chennai Super Kings          Chennai Super Kings           bat
# 2                Rajasthan Royals             Rajasthan Royals           bat
# 3     Royal Challengers Bengaluru               Mumbai Indians           bat
# 4                 Deccan Chargers              Deccan Chargers           bat
# ...                           ...                          ...           ...
# 1090          Sunrisers Hyderabad                 Punjab Kings           bat
# 1091        Kolkata Knight Riders          Sunrisers Hyderabad           bat
# 1092             Rajasthan Royals             Rajasthan Royals         field
# 1093             Rajasthan Royals             Rajasthan Royals         field
# 1094        Kolkata Knight Riders          Sunrisers Hyderabad           bat
#
#                            winner   result  result_margin  target_runs  \
# 0           Kolkata Knight Riders     runs          140.0        223.0
# 1             Chennai Super Kings     runs           33.0        241.0
# 2                  Delhi Capitals  wickets            9.0        130.0
# 3     Royal Challengers Bengaluru  wickets            5.0        166.0
# 4           Kolkata Knight Riders  wickets            5.0        111.0
# ...                           ...      ...            ...          ...
# 1090          Sunrisers Hyderabad  wickets            4.0        215.0
# 1091        Kolkata Knight Riders  wickets            8.0        160.0
# 1092             Rajasthan Royals  wickets            4.0        173.0
# 1093          Sunrisers Hyderabad     runs           36.0        176.0
# 1094        Kolkata Knight Riders  wickets            8.0        114.0
#
#       target_overs super_over         method
# 0             20.0          N  Normal method
# 1             20.0          N  Normal method
# 2             20.0          N  Normal method
# 3             20.0          N  Normal method
# 4             20.0          N  Normal method
# ...            ...        ...            ...
# 1090          20.0          N  Normal method
# 1091          20.0          N  Normal method
# 1092          20.0          N  Normal method
# 1093          20.0          N  Normal method
# 1094          20.0          N  Normal method
#
# [1095 rows x 18 columns]

# %%
# Question to be solve?
# # all Season Winner team
# # Toss_dicision_value_counts
# # Result type value_counts
# # Top 10 target Runs
# # Maximum Result Margin Wins
# # Top 5 Result Margin Wins
# # Top 10 player_of_match
# # Season Player of the match

# %% [markdown]
# ## Q1: All Season Winner team

# %%
Final_matche[['Winning year','winner' ]].sort_values('Winning year')
# Out:
#       Winning year                 winner
# 57            2008       Rajasthan Royals
# 114           2009        Deccan Chargers
# 174           2010    Chennai Super Kings
# 247           2011    Chennai Super Kings
# 321           2012  Kolkata Knight Riders
# 397           2013         Mumbai Indians
# 457           2014  Kolkata Knight Riders
# 516           2015         Mumbai Indians
# 576           2016    Sunrisers Hyderabad
# 635           2017         Mumbai Indians
# 695           2018    Chennai Super Kings
# 755           2019         Mumbai Indians
# 815           2020         Mumbai Indians
# 875           2021    Chennai Super Kings
# 949           2022         Gujarat Titans
# 1023          2023    Chennai Super Kings
# 1094          2024  Kolkata Knight Riders

# %% [markdown]
# ## Q2:Top Match Winner team

# %%
df_matches['winner'].value_counts().head(10)
# Out:
# winner
# Mumbai Indians                 144
# Chennai Super Kings            138
# Kolkata Knight Riders          131
# Royal Challengers Bengaluru    123
# Delhi Capitals                 115
# Rajasthan Royals               112
# Punjab Kings                   112
# Sunrisers Hyderabad             88
# Deccan Chargers                 29
# Gujarat Titans                  28
# Name: count, dtype: int64

# %%
# All Univariate analysis
num_cols = df_matches.describe()
cat_cols = df_matches.describe(include = 'O').columns

# %%
print(num_cols)
# Out:
#                  id                           date  result_margin  \
# count  1.095000e+03                           1095    1095.000000
# mean   9.048283e+05  2016-06-25 11:39:36.986301184      16.959817
# min    3.359820e+05            2008-04-18 00:00:00       0.000000
# 25%    5.483315e+05            2012-04-21 00:00:00       5.000000
# 50%    9.809610e+05            2016-05-03 00:00:00       8.000000
# 75%    1.254062e+06            2021-04-13 12:00:00      19.000000
# max    1.426312e+06            2024-05-26 00:00:00     146.000000
# std    3.677402e+05                            NaN      21.714792
#
#        target_runs  target_overs
# count  1095.000000   1095.000000
# mean    165.230137     19.705205
# min       0.000000      0.000000
# 25%     146.000000     20.000000
# 50%     166.000000     20.000000
# 75%     187.000000     20.000000
# max     288.000000     20.000000
# std      34.487313      1.887000

# %%
print(cat_cols)
# Out:
# Index(['season', 'city', 'match_type', 'player_of_match', 'venue', 'team1',
#        'team2', 'toss_winner', 'toss_decision', 'winner', 'result',
#        'super_over', 'method'],
#       dtype='object')

# %%
for i in cat_cols:
    try:
        temp_df = df_matches[i].value_counts().head(10).sort_values(ascending = True)
        x = temp_df.index
        y = temp_df.values
        plt.title(f'Top 10 Analysis by {i}')
        ax = plt.barh(x,y,color = sns.color_palette('cool',10))
        plt.bar_label(ax)
        plt.xticks(rotation = 85)
        plt.show()
    except:
        pass

# %%
plt.figure(figsize=(30,45))
for j,i in enumerate(cat_cols):
        temp_df = df_matches[i].value_counts().head(10).sort_values(ascending = True)
        x = temp_df.index
        y = temp_df.values

        
        plt.subplot(7,2,j+1)
        plt.title(f'Top 10 Analysis by {i}')
        colors = ['cool','mako','rainbow','magma','hot']
        import random
        ax = plt.barh(x,y,color = sns.color_palette(random.choice(colors),10))
        plt.bar_label(ax)
        plt.xticks(rotation = 85)
plt.savefig('All_Categorical_Analysis.jpeg',dpi = 300)
plt.show()
print('Done')
# Out:
# Done

# %%
# Seaborn dataset, sklearn dataset
# pandas
# concat
# merge, joins
# pivot table
# matplotlib
# seaborn
# Recap
# # Corr
# # outliers detection

# %%
# df_deliveries.sample()

# %%
# Top 10 target Runs
# Maximum Result Margin Wins
# Top 5 Result Margin Wins
# Season Player of the match

# %%
num_cols = df_matches.describe().columns

num_cols = list(num_cols)
num_cols.remove('id')
num_cols.remove('date')
num_cols.remove('target_overs')
num_cols
# Out:
# ['result_margin', 'target_runs']

# %%
# Numerical Histogram

plt.figure(figsize=(10,4))
for j,i in enumerate(num_cols):
    plt.subplot(1,2,j+1)
    plt.title(f"Distribution Anaysis for {i}")
    plt.hist(df_matches[i],color = 'red')
plt.show()

# %%
plt.figure(figsize=(10,4))
for j,i in enumerate(num_cols):
    plt.subplot(1,2,j+1)
    plt.title(f"Distribution Anaysis for {i}")
    sns.kdeplot(df_matches[i],color = 'red')
plt.show()

# %%
plt.figure(figsize=(10,4))
for j,i in enumerate(num_cols):
    plt.subplot(1,2,j+1)
    plt.title(f"Distribution Anaysis for {i}")
    sns.histplot(df_matches[i],color = 'blue', kde = True)
plt.show()

# %%
# Max Target Runs which team?

df_matches[df_matches['target_runs'] == df_matches['target_runs'].max()]
# Out:
#            id season       city       date match_type player_of_match  \
# 1053  1426268   2024  Bangalore 2024-04-15     League         TM Head
#
#                       venue                team1                        team2  \
# 1053  M Chinnaswamy Stadium  Sunrisers Hyderabad  Royal Challengers Bengaluru
#
#                       toss_winner toss_decision               winner result  \
# 1053  Royal Challengers Bengaluru         field  Sunrisers Hyderabad   runs
#
#       result_margin  target_runs  target_overs super_over         method
# 1053           25.0        288.0          20.0          N  Normal method

# %%
# Min Target Runs which team?
temp_df = df_matches[(df_matches['winner'] != 'No winner') & (df_matches['method'] == 'Normal method')]
temp_df[temp_df['target_runs'] == temp_df['target_runs'].min()]
# Out:
#           id season       city       date match_type         player_of_match  \
# 241   501265   2011      Delhi 2011-05-21     League  No Player of the match
# 485   829763   2015  Bangalore 2015-04-29     League  No Player of the match
# 994  1359519   2023    Lucknow 2023-05-03     League  No Player of the match
#
#                                                  venue  \
# 241                               Arun Jaitley Stadium
# 485                              M Chinnaswamy Stadium
# 994  Bharat Ratna Shri Atal Bihari Vajpayee Ekana C...
#
#                            team1                    team2  \
# 241               Delhi Capitals  Rising Pune Supergiants
# 485  Royal Challengers Bengaluru         Rajasthan Royals
# 994         Lucknow Super Giants      Chennai Super Kings
#
#              toss_winner toss_decision     winner     result  result_margin  \
# 241       Delhi Capitals           bat  No Winner  no result            0.0
# 485     Rajasthan Royals         field  No Winner  no result            0.0
# 994  Chennai Super Kings         field  No Winner  no result            0.0
#
#      target_runs  target_overs super_over         method
# 241          0.0           0.0          N  Normal method
# 485          0.0           0.0          N  Normal method
# 994          0.0           0.0          N  Normal method

# %%
df_matches[df_matches['date'].dt.year == 2017].sort_values(by = 'target_runs')
# Out:
#           id season        city       date   match_type    player_of_match  \
# 633  1082648   2017   Bangalore 2017-05-17   Eliminator    NM Coulter-Nile
# 611  1082626   2017  Chandigarh 2017-04-30       League     Sandeep Sharma
# 630  1082645   2017        Pune 2017-05-14       League         JD Unadkat
# 634  1082649   2017   Bangalore 2017-05-19  Qualifier 2          KV Sharma
# 635  1082650   2017   Hyderabad 2017-05-21        Final          KH Pandya
# 603  1082617   2017     Kolkata 2017-04-23       League    NM Coulter-Nile
# 606  1082621   2017   Bangalore 2017-04-27       League             AJ Tye
# 582  1082596   2017   Hyderabad 2017-04-09       League        Rashid Khan
# 623  1082638   2017   Hyderabad 2017-05-08       League           S Dhawan
# 618  1082633   2017   Bangalore 2017-05-05       League     Sandeep Sharma
# 588  1082602   2017   Bangalore 2017-04-14       League         KA Pollard
# 600  1082614   2017      Mumbai 2017-04-22       League     MJ McClenaghan
# 584  1082598   2017      Indore 2017-04-10       League           AR Patel
# 619  1082634   2017   Hyderabad 2017-05-06       League         JD Unadkat
# 610  1082625   2017      Rajkot 2017-04-29       League          KH Pandya
# 628  1082643   2017      Kanpur 2017-05-13       League     Mohammed Siraj
# 616  1082631   2017     Kolkata 2017-05-03       League        RA Tripathi
# 581  1082595   2017   Bangalore 2017-04-08       League          KM Jadhav
# 609  1082624   2017        Pune 2017-04-29       League        LH Ferguson
# 586  1082600   2017      Mumbai 2017-04-12       League          JJ Bumrah
# 621  1082636   2017   Bangalore 2017-05-07       League          SP Narine
# 595  1082609   2017   Hyderabad 2017-04-17       League            B Kumar
# 607  1082622   2017     Kolkata 2017-04-28       League          G Gambhir
# 604  1082618   2017      Mumbai 2017-04-24       League          BA Stokes
# 631  1082646   2017       Delhi 2017-05-14       League           HV Patel
# 614  1082629   2017        Pune 2017-05-01       League          BA Stokes
# 593  1082607   2017   Bangalore 2017-04-16       League          BA Stokes
# 613  1082628   2017      Mumbai 2017-05-01       League          RG Sharma
# 632  1082647   2017      Mumbai 2017-05-16  Qualifier 1  Washington Sundar
# 580  1082594   2017      Indore 2017-04-08       League         GJ Maxwell
# 624  1082639   2017  Chandigarh 2017-05-09       League          MM Sharma
# 627  1082642   2017       Delhi 2017-05-12       League            KK Nair
# 594  1082608   2017       Delhi 2017-04-17       League    NM Coulter-Nile
# 587  1082601   2017     Kolkata 2017-04-13       League          SP Narine
# 589  1082603   2017      Rajkot 2017-04-14       League             AJ Tye
# 590  1082604   2017     Kolkata 2017-04-15       League         RV Uthappa
# 629  1082644   2017     Kolkata 2017-05-13       League          AT Rayudu
# 592  1082606   2017      Mumbai 2017-04-16       League             N Rana
# 601  1082615   2017        Pune 2017-04-22       League           MS Dhoni
# 583  1082597   2017      Mumbai 2017-04-09       League             N Rana
# 605  1082620   2017        Pune 2017-04-26       League         RV Uthappa
# 579  1082593   2017      Rajkot 2017-04-07       League            CA Lynn
# 578  1082592   2017        Pune 2017-04-06       League          SPD Smith
# 615  1082630   2017       Delhi 2017-05-02       League     Mohammed Shami
# 599  1082613   2017     Kolkata 2017-04-21       League           SK Raina
# 602  1082616   2017      Rajkot 2017-04-23       League            HM Amla
# 591  1082605   2017       Delhi 2017-04-15       League        CJ Anderson
# 622  1082637   2017  Chandigarh 2017-05-07       League           DR Smith
# 597  1082611   2017   Hyderabad 2017-04-19       League      KS Williamson
# 625  1082640   2017      Kanpur 2017-05-10       League            SS Iyer
# 598  1082612   2017      Indore 2017-04-20       League         JC Buttler
# 585  1082599   2017        Pune 2017-04-11       League          SV Samson
# 577  1082591   2017   Hyderabad 2017-04-05       League       Yuvraj Singh
# 608  1082623   2017  Chandigarh 2017-04-28       League        Rashid Khan
# 617  1082632   2017       Delhi 2017-05-04       League            RR Pant
# 612  1082627   2017   Hyderabad 2017-04-30       League          DA Warner
# 620  1082635   2017       Delhi 2017-05-06       League        LMP Simmons
# 596  1082610   2017      Rajkot 2017-04-18       League           CH Gayle
# 626  1082641   2017      Mumbai 2017-05-11       League            WP Saha
#
#                                        venue                        team1  \
# 633                    M Chinnaswamy Stadium          Sunrisers Hyderabad
# 611       Punjab Cricket Association Stadium                 Punjab Kings
# 630  Maharashtra Cricket Association Stadium      Rising Pune Supergiants
# 634                    M Chinnaswamy Stadium               Mumbai Indians
# 635       Rajiv Gandhi International Stadium               Mumbai Indians
# 603                             Eden Gardens        Kolkata Knight Riders
# 606                    M Chinnaswamy Stadium  Royal Challengers Bengaluru
# 582       Rajiv Gandhi International Stadium          Sunrisers Hyderabad
# 623       Rajiv Gandhi International Stadium          Sunrisers Hyderabad
# 618                    M Chinnaswamy Stadium  Royal Challengers Bengaluru
# 588                    M Chinnaswamy Stadium  Royal Challengers Bengaluru
# 600                         Wankhede Stadium               Mumbai Indians
# 584                   Holkar Cricket Stadium                 Punjab Kings
# 619       Rajiv Gandhi International Stadium          Sunrisers Hyderabad
# 610   Saurashtra Cricket Association Stadium                Gujarat Lions
# 628                               Green Park                Gujarat Lions
# 616                             Eden Gardens        Kolkata Knight Riders
# 581                    M Chinnaswamy Stadium  Royal Challengers Bengaluru
# 609  Maharashtra Cricket Association Stadium      Rising Pune Supergiants
# 586                         Wankhede Stadium               Mumbai Indians
# 621                    M Chinnaswamy Stadium  Royal Challengers Bengaluru
# 595       Rajiv Gandhi International Stadium          Sunrisers Hyderabad
# 607                             Eden Gardens        Kolkata Knight Riders
# 604                         Wankhede Stadium               Mumbai Indians
# 631                     Arun Jaitley Stadium               Delhi Capitals
# 614  Maharashtra Cricket Association Stadium      Rising Pune Supergiants
# 593                    M Chinnaswamy Stadium  Royal Challengers Bengaluru
# 613                         Wankhede Stadium               Mumbai Indians
# 632                         Wankhede Stadium               Mumbai Indians
# 580                   Holkar Cricket Stadium                 Punjab Kings
# 624       Punjab Cricket Association Stadium                 Punjab Kings
# 627                     Arun Jaitley Stadium               Delhi Capitals
# 594                     Arun Jaitley Stadium               Delhi Capitals
# 587                             Eden Gardens        Kolkata Knight Riders
# 589   Saurashtra Cricket Association Stadium                Gujarat Lions
# 590                             Eden Gardens        Kolkata Knight Riders
# 629                             Eden Gardens        Kolkata Knight Riders
# 592                         Wankhede Stadium               Mumbai Indians
# 601  Maharashtra Cricket Association Stadium      Rising Pune Supergiants
# 583                         Wankhede Stadium               Mumbai Indians
# 605  Maharashtra Cricket Association Stadium      Rising Pune Supergiants
# 579   Saurashtra Cricket Association Stadium                Gujarat Lions
# 578  Maharashtra Cricket Association Stadium      Rising Pune Supergiants
# 615                     Arun Jaitley Stadium               Delhi Capitals
# 599                             Eden Gardens        Kolkata Knight Riders
# 602   Saurashtra Cricket Association Stadium                Gujarat Lions
# 591                     Arun Jaitley Stadium               Delhi Capitals
# 622       Punjab Cricket Association Stadium                 Punjab Kings
# 597       Rajiv Gandhi International Stadium          Sunrisers Hyderabad
# 625                               Green Park                Gujarat Lions
# 598                   Holkar Cricket Stadium                 Punjab Kings
# 585  Maharashtra Cricket Association Stadium      Rising Pune Supergiants
# 577       Rajiv Gandhi International Stadium          Sunrisers Hyderabad
# 608       Punjab Cricket Association Stadium                 Punjab Kings
# 617                     Arun Jaitley Stadium               Delhi Capitals
# 612       Rajiv Gandhi International Stadium          Sunrisers Hyderabad
# 620                     Arun Jaitley Stadium               Delhi Capitals
# 596   Saurashtra Cricket Association Stadium                Gujarat Lions
# 626                         Wankhede Stadium               Mumbai Indians
#
#                            team2                  toss_winner toss_decision  \
# 633        Kolkata Knight Riders        Kolkata Knight Riders         field
# 611               Delhi Capitals                 Punjab Kings         field
# 630                 Punjab Kings      Rising Pune Supergiants         field
# 634        Kolkata Knight Riders               Mumbai Indians         field
# 635      Rising Pune Supergiants               Mumbai Indians           bat
# 603  Royal Challengers Bengaluru  Royal Challengers Bengaluru         field
# 606                Gujarat Lions                Gujarat Lions         field
# 582                Gujarat Lions          Sunrisers Hyderabad         field
# 623               Mumbai Indians               Mumbai Indians           bat
# 618                 Punjab Kings  Royal Challengers Bengaluru         field
# 588               Mumbai Indians               Mumbai Indians         field
# 600               Delhi Capitals               Delhi Capitals         field
# 584  Royal Challengers Bengaluru  Royal Challengers Bengaluru           bat
# 619      Rising Pune Supergiants          Sunrisers Hyderabad         field
# 610               Mumbai Indians                Gujarat Lions           bat
# 628          Sunrisers Hyderabad          Sunrisers Hyderabad         field
# 616      Rising Pune Supergiants      Rising Pune Supergiants         field
# 581               Delhi Capitals  Royal Challengers Bengaluru           bat
# 609  Royal Challengers Bengaluru  Royal Challengers Bengaluru         field
# 586          Sunrisers Hyderabad               Mumbai Indians         field
# 621        Kolkata Knight Riders        Kolkata Knight Riders         field
# 595                 Punjab Kings                 Punjab Kings         field
# 607               Delhi Capitals        Kolkata Knight Riders         field
# 604      Rising Pune Supergiants               Mumbai Indians         field
# 631  Royal Challengers Bengaluru  Royal Challengers Bengaluru           bat
# 614                Gujarat Lions      Rising Pune Supergiants         field
# 593      Rising Pune Supergiants  Royal Challengers Bengaluru         field
# 613  Royal Challengers Bengaluru  Royal Challengers Bengaluru           bat
# 632      Rising Pune Supergiants               Mumbai Indians         field
# 580      Rising Pune Supergiants                 Punjab Kings         field
# 624        Kolkata Knight Riders        Kolkata Knight Riders         field
# 627      Rising Pune Supergiants               Delhi Capitals           bat
# 594        Kolkata Knight Riders               Delhi Capitals           bat
# 587                 Punjab Kings        Kolkata Knight Riders         field
# 589      Rising Pune Supergiants                Gujarat Lions         field
# 590          Sunrisers Hyderabad          Sunrisers Hyderabad         field
# 629               Mumbai Indians        Kolkata Knight Riders         field
# 592                Gujarat Lions               Mumbai Indians         field
# 601          Sunrisers Hyderabad      Rising Pune Supergiants         field
# 583        Kolkata Knight Riders               Mumbai Indians         field
# 605        Kolkata Knight Riders        Kolkata Knight Riders         field
# 579        Kolkata Knight Riders        Kolkata Knight Riders         field
# 578               Mumbai Indians      Rising Pune Supergiants         field
# 615          Sunrisers Hyderabad               Delhi Capitals         field
# 599                Gujarat Lions                Gujarat Lions         field
# 602                 Punjab Kings                Gujarat Lions         field
# 591                 Punjab Kings               Delhi Capitals           bat
# 622                Gujarat Lions                Gujarat Lions         field
# 597               Delhi Capitals          Sunrisers Hyderabad           bat
# 625               Delhi Capitals               Delhi Capitals         field
# 598               Mumbai Indians               Mumbai Indians         field
# 585               Delhi Capitals      Rising Pune Supergiants         field
# 577  Royal Challengers Bengaluru  Royal Challengers Bengaluru         field
# 608          Sunrisers Hyderabad                 Punjab Kings         field
# 617                Gujarat Lions               Delhi Capitals         field
# 612        Kolkata Knight Riders        Kolkata Knight Riders         field
# 620               Mumbai Indians               Delhi Capitals         field
# 596  Royal Challengers Bengaluru                Gujarat Lions         field
# 626                 Punjab Kings               Mumbai Indians         field
#
#                           winner   result  result_margin  target_runs  \
# 633        Kolkata Knight Riders  wickets            7.0         48.0
# 611                 Punjab Kings  wickets           10.0         68.0
# 630      Rising Pune Supergiants  wickets            9.0         74.0
# 634               Mumbai Indians  wickets            6.0        108.0
# 635               Mumbai Indians     runs            1.0        130.0
# 603        Kolkata Knight Riders     runs           82.0        132.0
# 606                Gujarat Lions  wickets            7.0        135.0
# 582          Sunrisers Hyderabad  wickets            9.0        136.0
# 623          Sunrisers Hyderabad  wickets            7.0        139.0
# 618                 Punjab Kings     runs           19.0        139.0
# 588               Mumbai Indians  wickets            4.0        143.0
# 600               Mumbai Indians     runs           14.0        143.0
# 584                 Punjab Kings  wickets            8.0        149.0
# 619      Rising Pune Supergiants     runs           12.0        149.0
# 610               Mumbai Indians      tie            0.0        154.0
# 628          Sunrisers Hyderabad  wickets            8.0        155.0
# 616      Rising Pune Supergiants  wickets            4.0        156.0
# 581  Royal Challengers Bengaluru     runs           15.0        158.0
# 609      Rising Pune Supergiants     runs           61.0        158.0
# 586               Mumbai Indians  wickets            4.0        159.0
# 621        Kolkata Knight Riders  wickets            6.0        159.0
# 595          Sunrisers Hyderabad     runs            5.0        160.0
# 607        Kolkata Knight Riders  wickets            7.0        161.0
# 604      Rising Pune Supergiants     runs            3.0        161.0
# 631  Royal Challengers Bengaluru     runs           10.0        162.0
# 614      Rising Pune Supergiants  wickets            5.0        162.0
# 593      Rising Pune Supergiants     runs           27.0        162.0
# 613               Mumbai Indians  wickets            5.0        163.0
# 632      Rising Pune Supergiants     runs           20.0        163.0
# 580                 Punjab Kings  wickets            6.0        164.0
# 624                 Punjab Kings     runs           14.0        168.0
# 627               Delhi Capitals     runs            7.0        169.0
# 594        Kolkata Knight Riders  wickets            4.0        169.0
# 587        Kolkata Knight Riders  wickets            8.0        171.0
# 589                Gujarat Lions  wickets            7.0        172.0
# 590        Kolkata Knight Riders     runs           17.0        173.0
# 629               Mumbai Indians     runs            9.0        174.0
# 592               Mumbai Indians  wickets            6.0        177.0
# 601      Rising Pune Supergiants  wickets            6.0        177.0
# 583               Mumbai Indians  wickets            4.0        179.0
# 605        Kolkata Knight Riders  wickets            7.0        183.0
# 579        Kolkata Knight Riders  wickets           10.0        184.0
# 578      Rising Pune Supergiants  wickets            7.0        185.0
# 615               Delhi Capitals  wickets            6.0        186.0
# 599                Gujarat Lions  wickets            4.0        188.0
# 602                 Punjab Kings     runs           26.0        189.0
# 591               Delhi Capitals     runs           51.0        189.0
# 622                Gujarat Lions  wickets            6.0        190.0
# 597          Sunrisers Hyderabad     runs           15.0        192.0
# 625               Delhi Capitals  wickets            2.0        196.0
# 598               Mumbai Indians  wickets            8.0        199.0
# 585               Delhi Capitals     runs           97.0        206.0
# 577          Sunrisers Hyderabad     runs           35.0        208.0
# 608          Sunrisers Hyderabad     runs           26.0        208.0
# 617               Delhi Capitals  wickets            7.0        209.0
# 612          Sunrisers Hyderabad     runs           48.0        210.0
# 620               Mumbai Indians     runs          146.0        213.0
# 596  Royal Challengers Bengaluru     runs           21.0        214.0
# 626                 Punjab Kings     runs            7.0        231.0
#
#      target_overs super_over         method
# 633           6.0          N            D/L
# 611          20.0          N  Normal method
# 630          20.0          N  Normal method
# 634          20.0          N  Normal method
# 635          20.0          N  Normal method
# 603          20.0          N  Normal method
# 606          20.0          N  Normal method
# 582          20.0          N  Normal method
# 623          20.0          N  Normal method
# 618          20.0          N  Normal method
# 588          20.0          N  Normal method
# 600          20.0          N  Normal method
# 584          20.0          N  Normal method
# 619          20.0          N  Normal method
# 610          20.0          Y  Normal method
# 628          20.0          N  Normal method
# 616          20.0          N  Normal method
# 581          20.0          N  Normal method
# 609          20.0          N  Normal method
# 586          20.0          N  Normal method
# 621          20.0          N  Normal method
# 595          20.0          N  Normal method
# 607          20.0          N  Normal method
# 604          20.0          N  Normal method
# 631          20.0          N  Normal method
# 614          20.0          N  Normal method
# 593          20.0          N  Normal method
# 613          20.0          N  Normal method
# 632          20.0          N  Normal method
# 580          20.0          N  Normal method
# 624          20.0          N  Normal method
# 627          20.0          N  Normal method
# 594          20.0          N  Normal method
# 587          20.0          N  Normal method
# 589          20.0          N  Normal method
# 590          20.0          N  Normal method
# 629          20.0          N  Normal method
# 592          20.0          N  Normal method
# 601          20.0          N  Normal method
# 583          20.0          N  Normal method
# 605          20.0          N  Normal method
# 579          20.0          N  Normal method
# 578          20.0          N  Normal method
# 615          20.0          N  Normal method
# 599          20.0          N  Normal method
# 602          20.0          N  Normal method
# 591          20.0          N  Normal method
# 622          20.0          N  Normal method
# 597          20.0          N  Normal method
# 625          20.0          N  Normal method
# 598          20.0          N  Normal method
# 585          20.0          N  Normal method
# 577          20.0          N  Normal method
# 608          20.0          N  Normal method
# 617          20.0          N  Normal method
# 612          20.0          N  Normal method
# 620          20.0          N  Normal method
# 596          20.0          N  Normal method
# 626          20.0          N  Normal method

# %%
# LOC. , ILOC
# Index = 603
df_matches.iloc[603,1:]
# Out:
# season                                    2017
# city                                   Kolkata
# date                       2017-04-23 00:00:00
# match_type                              League
# player_of_match                NM Coulter-Nile
# venue                             Eden Gardens
# team1                    Kolkata Knight Riders
# team2              Royal Challengers Bengaluru
# toss_winner        Royal Challengers Bengaluru
# toss_decision                            field
# winner                   Kolkata Knight Riders
# result                                    runs
# result_margin                             82.0
# target_runs                              132.0
# target_overs                              20.0
# super_over                                   N
# method                           Normal method
# Name: 603, dtype: object

# %%
print(num_cols)
print(cat_cols)
# Out:
# ['result_margin', 'target_runs']
# Index(['season', 'city', 'match_type', 'player_of_match', 'venue', 'team1',
#        'team2', 'toss_winner', 'toss_decision', 'winner', 'result',
#        'super_over', 'method'],
#       dtype='object')

# %%
df_matches.columns
# Out:
# Index(['id', 'season', 'city', 'date', 'match_type', 'player_of_match',
#        'venue', 'team1', 'team2', 'toss_winner', 'toss_decision', 'winner',
#        'result', 'result_margin', 'target_runs', 'target_overs', 'super_over',
#        'method'],
#       dtype='object')

# %%
# stadium wise Team highest score
df_matches.groupby(['venue','team1'])['target_runs'].agg(['max','min','mean'])
# Out:
#                                                      max    min        mean
# venue                 team1
# Arun Jaitley Stadium  Chennai Super Kings          224.0  193.0  212.000000
#                       Delhi Capitals               258.0    0.0  164.971831
#                       Gujarat Lions                163.0  163.0  163.000000
#                       Kolkata Knight Riders        186.0  128.0  157.000000
#                       Mumbai Indians               169.0  169.0  169.000000
# ...                                                  ...    ...         ...
# Zayed Cricket Stadium Kolkata Knight Riders        172.0  172.0  172.000000
#                       Mumbai Indians               236.0  156.0  196.000000
#                       Punjab Kings                 136.0  136.0  136.000000
#                       Royal Challengers Bengaluru   93.0   93.0   93.000000
#                       Sunrisers Hyderabad          142.0  142.0  142.000000
#
# [211 rows x 3 columns]

# %%
df_matches.groupby(['target_runs','team1'])['venue'].max().tail(10)
# Out:
# target_runs  team1
# 247.0        Chennai Super Kings                                       Ma Chidambaram Stadium
# 249.0        Royal Challengers Bengaluru                                M Chinnaswamy Stadium
# 258.0        Delhi Capitals                                              Arun Jaitley Stadium
#              Lucknow Super Giants                          Punjab Cricket Association Stadium
# 262.0        Kolkata Knight Riders                                               Eden Gardens
# 264.0        Royal Challengers Bengaluru                                M Chinnaswamy Stadium
# 267.0        Sunrisers Hyderabad                                         Arun Jaitley Stadium
# 273.0        Kolkata Knight Riders          Dr. Y.S. Rajasekhara Reddy Aca-Vdca Cricket St...
# 278.0        Sunrisers Hyderabad                           Rajiv Gandhi International Stadium
# 288.0        Sunrisers Hyderabad                                        M Chinnaswamy Stadium
# Name: venue, dtype: object

# %%
# Pivot table

df_matches['years'] = df_matches['date'].dt.year
df_matches.columns
# Out:
# Index(['id', 'season', 'city', 'date', 'match_type', 'player_of_match',
#        'venue', 'team1', 'team2', 'toss_winner', 'toss_decision', 'winner',
#        'result', 'result_margin', 'target_runs', 'target_overs', 'super_over',
#        'method', 'years'],
#       dtype='object')

# %%
all_team_year_df = df_matches.pivot_table(index ='years', columns = 'team1',values = 'target_runs')
all_team_year_df = all_team_year_df.round(0)

# %%
plt.figure(figsize=(15,10))
# pd.options.display.float_format = '{:.2f}'.format
# pd.set_option('display.float_format', '{:.2f}'.format)
sns.heatmap(all_team_year_df,fmt = "" ,annot = True)
plt.show()

# %%
all_team_year_df_2 = df_matches.pivot_table(index ='years', columns = 'team2',values = 'target_runs')
all_team_year_df_2 = all_team_year_df_2.round(0)

# %%
plt.figure(figsize=(15,10))
# pd.options.display.float_format = '{:.2f}'.format
# pd.set_option('display.float_format', '{:.2f}'.format)
sns.heatmap(all_team_year_df_2,fmt = "" ,annot = True)
plt.show()

# %%
all_team_year_df_min = df_matches.pivot_table(index ='years', columns = 'team1',values = 'target_runs',aggfunc ='min')
all_team_year_df_min = all_team_year_df_min.round(0)
plt.figure(figsize=(15,10))
# pd.options.display.float_format = '{:.2f}'.format
# pd.set_option('display.float_format', '{:.2f}'.format)
sns.heatmap(all_team_year_df_min,fmt = "" ,annot = True, cmap = 'mako')
plt.title('IPL all session Min Team Score')
plt.show()

# %%
all_team_year_df_max = df_matches.pivot_table(index ='years', columns = 'team1',values = 'target_runs',aggfunc ='max')
all_team_year_df_max = all_team_year_df_max.round(0)
plt.figure(figsize=(15,10))
# pd.options.display.float_format = '{:.2f}'.format
# pd.set_option('display.float_format', '{:.2f}'.format)
sns.heatmap(all_team_year_df_max,fmt = "" ,annot = True, cmap = 'cool')
plt.title('IPL all session Team Max Score')
plt.show()

# %%
# Team2 all year analysis

# %%
# LOC vs ILOC
# LOC: Location Name
# ILOC: Index Pass

# %%
df_matches.loc[50:55,['team1','team2','result']]
# Out:
#                           team1                team2   result
# 50        Kolkata Knight Riders         Punjab Kings  wickets
# 51             Rajasthan Royals       Mumbai Indians  wickets
# 52              Deccan Chargers  Chennai Super Kings  wickets
# 53  Royal Challengers Bengaluru       Mumbai Indians  wickets
# 54                 Punjab Kings     Rajasthan Royals     runs
# 55               Delhi Capitals     Rajasthan Royals     runs

# %%
df_matches.iloc[50:55,[7,8,12]]
# Out:
#                           team1                team2   result
# 50        Kolkata Knight Riders         Punjab Kings  wickets
# 51             Rajasthan Royals       Mumbai Indians  wickets
# 52              Deccan Chargers  Chennai Super Kings  wickets
# 53  Royal Challengers Bengaluru       Mumbai Indians  wickets
# 54                 Punjab Kings     Rajasthan Royals     runs

# %%
# 2016 > all rows and columns last 3

# %%
rows = df_matches[df_matches['years']>=2016].index
df_matches.iloc[rows,-3:]
# Out:
#      super_over         method  years
# 517           N  Normal method   2016
# 518           N  Normal method   2016
# 519           N  Normal method   2016
# 520           N  Normal method   2016
# 521           N  Normal method   2016
# ...         ...            ...    ...
# 1090          N  Normal method   2024
# 1091          N  Normal method   2024
# 1092          N  Normal method   2024
# 1093          N  Normal method   2024
# 1094          N  Normal method   2024
#
# [578 rows x 3 columns]

# %%
df_deliveries.sample()
# Out:
#         match_id  inning    batting_team     bowling_team  over  ball  \
# 173626   1178412       2  Delhi Capitals  Kings XI Punjab     3     5
#
#          batter      bowler non_striker  batsman_runs  extra_runs  total_runs  \
# 173626  SS Iyer  GC Viljoen    S Dhawan             1           0           1
#
#        extras_type  is_wicket player_dismissed dismissal_kind fielder
# 173626         NaN          0              NaN            NaN     NaN

# %%
df_deliveries.iloc[123257,:]
# Out:
# match_id                                 980907
# inning                                        1
# batting_team        Royal Challengers Bangalore
# bowling_team                Sunrisers Hyderabad
# over                                         16
# ball                                          6
# batter                                SR Watson
# bowler                                KV Sharma
# non_striker                      AB de Villiers
# batsman_runs                                  6
# extra_runs                                    0
# total_runs                                    6
# extras_type                                 NaN
# is_wicket                                     0
# player_dismissed                            NaN
# dismissal_kind                              NaN
# fielder                                     NaN
# Name: 123257, dtype: object

# %%
df_deliveries.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 260920 entries, 0 to 260919
# Data columns (total 17 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   match_id          260920 non-null  int64
#  1   inning            260920 non-null  int64
#  2   batting_team      260920 non-null  object
#  3   bowling_team      260920 non-null  object
#  4   over              260920 non-null  int64
#  5   ball              260920 non-null  int64
#  6   batter            260920 non-null  object
#  7   bowler            260920 non-null  object
#  8   non_striker       260920 non-null  object
#  9   batsman_runs      260920 non-null  int64
#  10  extra_runs        260920 non-null  int64
#  11  total_runs        260920 non-null  int64
#  12  extras_type       14125 non-null   object
#  13  is_wicket         260920 non-null  int64
#  14  player_dismissed  12950 non-null   object
#  15  dismissal_kind    12950 non-null   object
#  16  fielder           9354 non-null    object
# dtypes: int64(8), object(9)
# memory usage: 33.8+ MB

# %%
df_deliveries.isna().sum().sort_values(ascending = False)
# Out:
# fielder             251566
# dismissal_kind      247970
# player_dismissed    247970
# extras_type         246795
# batsman_runs             0
# is_wicket                0
# total_runs               0
# extra_runs               0
# match_id                 0
# inning                   0
# bowler                   0
# batter                   0
# ball                     0
# over                     0
# bowling_team             0
# batting_team             0
# non_striker              0
# dtype: int64

# %%
df_deliveries.loc[:,['fielder','dismissal_kind','player_dismissed','extras_type']]
# Out:
#        fielder dismissal_kind player_dismissed extras_type
# 0          NaN            NaN              NaN     legbyes
# 1          NaN            NaN              NaN         NaN
# 2          NaN            NaN              NaN       wides
# 3          NaN            NaN              NaN         NaN
# 4          NaN            NaN              NaN         NaN
# ...        ...            ...              ...         ...
# 260915     NaN            NaN              NaN         NaN
# 260916     NaN            NaN              NaN         NaN
# 260917     NaN            NaN              NaN         NaN
# 260918     NaN            NaN              NaN         NaN
# 260919     NaN            NaN              NaN         NaN
#
# [260920 rows x 4 columns]

# %%
normal_cols = ['fielder','dismissal_kind','player_dismissed','extras_type']

# %%
for i in normal_cols:
    print(f'Analysis for {i} \n\n')
    display(df_deliveries[i].value_counts().head(10))
# Out:
# Analysis for fielder
# fielder
# MS Dhoni          220
# KD Karthik        199
# AB de Villiers    141
# RV Uthappa        133
# WP Saha           131
# V Kohli           131
# SK Raina          119
# RA Jadeja         116
# SV Samson         115
# RG Sharma         111
# Name: count, dtype: int64
# Analysis for dismissal_kind
# dismissal_kind
# caught                   8063
# bowled                   2212
# run out                  1114
# lbw                       800
# caught and bowled         367
# stumped                   358
# retired hurt               15
# hit wicket                 15
# obstructing the field       3
# retired out                 3
# Name: count, dtype: int64
# Analysis for player_dismissed
# player_dismissed
# RG Sharma     223
# V Kohli       207
# S Dhawan      193
# KD Karthik    184
# RV Uthappa    180
# SK Raina      171
# DA Warner     164
# AT Rayudu     155
# AM Rahane     154
# SV Samson     144
# Name: count, dtype: int64
# Analysis for extras_type
# extras_type
# wides      8380
# legbyes    4001
# noballs    1069
# byes        673
# penalty       2
# Name: count, dtype: int64

# %%
plt.title("Checking Null values Distribution")
sns.heatmap(df_deliveries.isna())
# Out:
# <Axes: title={'center': 'Checking Null values Distribution'}>

# %%
 # Filll NAN Values

df_deliveries.fillna('Unknown',inplace = True)
print('Done')
# Out:
# Done

# %%
plt.title("Checking Null values Distribution")
sns.heatmap(df_deliveries.isna())
plt.show()

# %%
df_deliveries.sample()
# Out:
#         match_id  inning                 batting_team         bowling_team  \
# 187127   1216525       1  Royal Challengers Bangalore  Chennai Super Kings
#
#         over  ball   batter     bowler        non_striker  batsman_runs  \
# 187127    11     1  V Kohli  RA Jadeja  Washington Sundar             1
#
#         extra_runs  total_runs extras_type  is_wicket player_dismissed  \
# 187127           0           1     Unknown          0          Unknown
#
#        dismissal_kind  fielder
# 187127        Unknown  Unknown

# %%
# batsman = 'DA Miller' #DA Miller

def get_player_performance_stats(batsman):

    player_df = df_deliveries[df_deliveries['batter'] == batsman]
    x = player_df['batsman_runs'].value_counts().sort_index().index
    y = player_df['batsman_runs'].value_counts().sort_index().values
    plt.figure(figsize=(4,2))
    plt.title(f'Analysis for {batsman}')
    ax = plt.bar(x,y,color = sns.color_palette('magma',7))
    plt.bar_label(ax)
    plt.show()
    
    total_runs = player_df['batsman_runs'].sum()
    
    print(f'{batsman} Total Runs in IPL History: {total_runs}')
    
    print(f'Batsman {batsman} Top 10 Performance Against Bowlers')
    perfomance_df = player_df.groupby('bowler')['batsman_runs'].agg(['sum','mean']).reset_index().sort_values(by ='sum',ascending =  False).head(10)
    display(perfomance_df)

# %%
all_batsman = df_deliveries['batter'].unique()
print('Done')
# Out:
# Done

# %%
import random
for i in random.choices(all_batsman,k = 5):
    get_player_performance_stats(i)
# Out:
# Saurav Chauhan Total Runs in IPL History: 18
# Batsman Saurav Chauhan Top 10 Performance Against Bowlers
#        bowler  sum  mean
# 5    R Ashwin    7  2.33
# 1   G Coetzee    6  1.20
# 2   JJ Bumrah    3  0.75
# 0  Avesh Khan    1  1.00
# 3    N Burger    1  1.00
# 4  PJ Cummins    0  0.00
# 6   YS Chahal    0  0.00
# K Gowtham Total Runs in IPL History: 247
# Batsman K Gowtham Top 10 Performance Against Bowlers
#                bowler  sum  mean
# 38           TA Boult   22  1.69
# 23          MM Sharma   19  3.17
# 15          JJ Bumrah   17  1.70
# 39         TG Southee   14  2.80
# 11          DL Chahar   14  1.75
# 18          KV Sharma   13  2.17
# 2          AD Russell   13  2.17
# 27  Mustafizur Rahman   13  3.25
# 10          DJ Willey   13  2.60
# 4            AR Patel   10  0.91
# GHS Garton Total Runs in IPL History: 2
# Batsman GHS Garton Top 10 Performance Against Bowlers
#            bowler  sum  mean
# 0         B Kumar    1  0.50
# 1       JO Holder    1  1.00
# 2  Mohammed Shami    0  0.00
# TR Birt Total Runs in IPL History: 75
# Batsman TR Birt Top 10 Performance Against Bowlers
#             bowler  sum  mean
# 7    R Vinay Kumar   26  2.36
# 5   P Parameswaran    9  2.25
# 3    Iqbal Abdulla    6  1.00
# 4          P Kumar    6  1.50
# 9        RJ Harris    6  2.00
# 11     S Sreesanth    6  1.50
# 6        PP Chawla    4  1.00
# 8        RA Jadeja    4  1.33
# 0         A Mishra    2  2.00
# 2     DT Christian    2  0.25
# NLTC Perera Total Runs in IPL History: 424
# Batsman NLTC Perera Top 10 Performance Against Bowlers
#            bowler  sum  mean
# 56      SP Narine   32  1.33
# 16       HV Patel   20  3.33
# 6   Azhar Mahmood   20  2.50
# 43        P Kumar   19  2.11
# 36     MN Samuels   16  2.29
# 27      KJ Abbott   16  2.67
# 44      PP Chawla   15  1.25
# 26    JP Faulkner   15  1.36
# 22     JD Unadkat   15  1.36
# 28      KK Cooper   13  1.30

# %%
# Data Frame JOIN

# %%
player_df.groupby('bowler')['batsman_runs'].agg(['sum','mean']).reset_index().sort_values(by ='sum',ascending =  False).head(10)
# Out:
#                 bowler  sum  mean
# 129          RA Jadeja  111  1.66
# 122           R Ashwin   82  1.12
# 173          YS Chahal   77  1.71
# 1             A Mishra   68  1.31
# 45            HV Patel   63  1.50
# 14          Avesh Khan   61  1.52
# 118          PP Chawla   60  1.18
# 90   M Prasidh Krishna   59  1.69
# 165           UT Yadav   55  1.34
# 151          SP Narine   51  1.34
