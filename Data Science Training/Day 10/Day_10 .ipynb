# %%
# Split
# where
# clip
# Broadcasting


# Pandas Introduction

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
arr = plt.imread('cloud.jpg')
arr
# Out:
# array([[[219, 234, 253],
#         [219, 234, 253],
#         [219, 234, 253],
#         ...,
#         [209, 220, 248],
#         [208, 219, 247],
#         [208, 219, 247]],
#
#        [[219, 234, 253],
#         [219, 234, 253],
#         [219, 234, 253],
#         ...,
#         [208, 219, 247],
#         [208, 219, 247],
#         [208, 219, 247]],
#
#        [[220, 235, 254],
#         [220, 235, 254],
#         [220, 235, 254],
#         ...,
#         [208, 219, 247],
#         [208, 219, 247],
#         [208, 219, 247]],
#
#        ...,
#
#        [[150, 178, 226],
#         [150, 178, 226],
#         [151, 179, 227],
#         ...,
#         [136, 171, 227],
#         [136, 171, 229],
#         [136, 171, 229]],
#
#        [[149, 177, 225],
#         [150, 178, 226],
#         [150, 178, 226],
#         ...,
#         [135, 170, 226],
#         [135, 170, 226],
#         [135, 170, 226]],
#
#        [[149, 177, 225],
#         [150, 178, 226],
#         [151, 179, 227],
#         ...,
#         [135, 170, 226],
#         [134, 169, 225],
#         [134, 169, 225]]], dtype=uint8)

# %%
cloud_arr = arr.copy()
plt.imshow(cloud_arr)

# %%
cloud_arr.shape
# Out:
# (2304, 3072, 3)

# %%
a = np.random.randint(0,255,(50,50,3))
plt.imshow(a)

# %%
while True:
    import numpy as np
    import matplotlib.pyplot as plt
    import time
    a = np.random.randint(0,255,(50,50,3))
    plt.imshow(a)
    plt.show()
    time.sleep(0.2)
    display(clear = True )

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
a = np.random.randint(0,255,(4,4,3))
a
# Out:
# array([[[223, 163, 237],
#         [239, 245, 216],
#         [ 29, 237,  39],
#         [114,  21,  41]],
#
#        [[155, 154,  97],
#         [187, 141,  85],
#         [231,  95, 164],
#         [162,  14, 226]],
#
#        [[213,  70,  93],
#         [207, 172, 113],
#         [110, 199, 164],
#         [  6, 204,  36]],
#
#        [[ 54, 148,  48],
#         [ 71, 126,  87],
#         [101, 221, 246],
#         [115, 214,  72]]])

# %%
final_arr = np.split(a,2)
len(final_arr)
# Out:
# 2

# %%
plt.imshow(a)

# %%
plt.imshow(final_arr[0])

# %%
plt.imshow(final_arr[1])

# %%
final_arrv = np.split(a,2, axis= 1)
len(final_arrv)
# Out:
# 2

# %%
plt.imshow(final_arrv[0])

# %%
plt.imshow(final_arrv[1])

# %%
arr_3_part = np.split(a,3,axis = 2)

# %%
plt.imshow(a)

# %%
plt.imshow(arr_3_part[0])

# %%
plt.imshow(arr_3_part[1])

# %%
plt.imshow(arr_3_part[2])

# %%
arr.shape
# Out:
# (2304, 3072, 3)

# %%
plt.imshow(np.split(arr,3,axis = 2)[0])

# %%
plt.imshow(np.split(arr,3,axis = 2)[1])

# %%
plt.imshow(np.split(arr,3,axis = 2)[2])

# %%
plt.imshow(np.split(arr,2,axis = 0)[0])

# %%
plt.imshow(np.split(arr,2,axis = 0)[1])

# %%
arr.shape
# Out:
# (2304, 3072, 3)

# %%
3072//3
# Out:
# 1024

# %%
plt.imshow(arr[:,:1024,:])

# %%
plt.imshow(arr[:,1024:1024*2,:])

# %%
plt.imshow(arr[:,1024*2:,:])

# %%
# where
# clip

# %%
a = np.random.randint(1,500,(4,4))
a
# Out:
# array([[270, 454, 484, 361],
#        [268, 111, 218, 393],
#        [283, 394, 113, 156],
#        [ 20, 139, 312, 333]])

# %%
np.where(a>200)
# Out:
# (array([0, 0, 0, 0, 1, 1, 1, 2, 2, 3, 3]),
#  array([0, 1, 2, 3, 0, 2, 3, 0, 1, 2, 3]))

# %%
np.where(a>200,'High Sales','Low Sales')
# Out:
# array([['High Sales', 'High Sales', 'High Sales', 'High Sales'],
#        ['High Sales', 'Low Sales', 'High Sales', 'High Sales'],
#        ['High Sales', 'High Sales', 'Low Sales', 'Low Sales'],
#        ['Low Sales', 'Low Sales', 'High Sales', 'High Sales']],
#       dtype='<U10')

# %%
np.where(a>200,'High Sales',a)
# Out:
# array([['High Sales', 'High Sales', 'High Sales', 'High Sales'],
#        ['High Sales', '111', 'High Sales', 'High Sales'],
#        ['High Sales', 'High Sales', '113', '156'],
#        ['20', '139', 'High Sales', 'High Sales']], dtype='<U21')

# %%
a
# Out:
# array([[270, 454, 484, 361],
#        [268, 111, 218, 393],
#        [283, 394, 113, 156],
#        [ 20, 139, 312, 333]])

# %%
np.clip(a,150,400) # outliers remove/replace
# Out:
# array([[270, 400, 400, 361],
#        [268, 150, 218, 393],
#        [283, 394, 150, 156],
#        [150, 150, 312, 333]])

# %%
# Broadcasting

# %%
a = np.random.randint(1,10,7)
b = np.random.randint(1,10,(2,7))

print(a)
print('-'*20)
print(b)
# Out:
# [3 8 7 2 7 6 7]
# --------------------
# [[3 9 9 7 3 2 6]
#  [9 5 5 2 1 3 8]]

# %%
a*b
# Out:
# array([[ 9, 72, 63, 14, 21, 12, 42],
#        [27, 40, 35,  4,  7, 18, 56]])

# %%
a +b
# Out:
# array([[ 6, 17, 16,  9, 10,  8, 13],
#        [12, 13, 12,  4,  8,  9, 15]])

# %%
c = np.random.randint(1,10,8)
d = np.random.randint(1,10,(7,8))

print(c)
print('-'*20)
print(d)
# Out:
# [8 6 1 7 7 4 9 9]
# --------------------
# [[4 2 5 7 1 2 2 9]
#  [3 1 9 9 1 2 5 8]
#  [3 2 6 2 5 7 2 2]
#  [2 5 4 5 4 5 4 9]
#  [4 2 7 7 8 3 9 1]
#  [9 8 1 1 1 8 3 1]
#  [7 5 3 1 4 7 3 1]]

# %%
c + d
# Out:
# array([[12,  8,  6, 14,  8,  6, 11, 18],
#        [11,  7, 10, 16,  8,  6, 14, 17],
#        [11,  8,  7,  9, 12, 11, 11, 11],
#        [10, 11,  5, 12, 11,  9, 13, 18],
#        [12,  8,  8, 14, 15,  7, 18, 10],
#        [17, 14,  2,  8,  8, 12, 12, 10],
#        [15, 11,  4,  8, 11, 11, 12, 10]])

# %% [markdown]
# ## Introduction to Pandas

# %%
# Data Science
# data : Explore (Exploratory Data Analysis)
# EDA

# %%
# # Anupam: lives in nainital
# # Piyush = 100
# # Explore
# Excel: EDA
# SQL :- EDA
# PowerBI: EDA
# Python: EDA

# %%
# Python : - Programming language
# pandas:  File Handling
# pandas: table

# %%
# dataframe: df

# %%
# Data Explore:- Report(Insights)

# Report>>>> Data Scientist

# %%
import pandas as pd
pd.__version__
# Out:
# '2.2.3'

# %%
import random

products = ['Chair','Tables','Laptop','Mobile Phone','Charger']
region = ['East','West','North','South']
all_date = pd.date_range('01-01-2025','23-07-2025')

data = {'Order_id':range(1,1001),
        'Date':random.choices(all_date,k=1000),
        'Region Name':random.choices(region,k = 1000),
        'Product Name':random.choices(products,k = 1000),
        'sales':np.random.randint(100,10000,1000),
        'Qty':np.random.randint(1,10,1000),
        'Profit':np.random.randint(-10000,10000,1000)}

table = pd.DataFrame(data)
table
# Out:
#      Order_id       Date Region Name  Product Name  sales  Qty  Profit
# 0           1 2025-02-20        West        Tables   8228    4    7910
# 1           2 2025-05-29       South         Chair   1149    8   -9739
# 2           3 2025-04-25        West        Laptop   1834    1    2909
# 3           4 2025-05-14       South        Laptop   4798    9   -9773
# 4           5 2025-07-18        West  Mobile Phone    808    8    -714
# ..        ...        ...         ...           ...    ...  ...     ...
# 995       996 2025-03-19        West       Charger    634    8   -1530
# 996       997 2025-03-21        East  Mobile Phone   3845    7   -1280
# 997       998 2025-07-07        West        Tables   5013    3   -6158
# 998       999 2025-05-19       South        Laptop   5634    3    3146
# 999      1000 2025-03-11       North  Mobile Phone   7932    7   -5417
#
# [1000 rows x 7 columns]

# %%
# date column

# %%
# top data.   # by default = 5
table.head(10)
# Out:
#    Order_id       Date Region Name  Product Name  sales  Qty  Profit
# 0         1 2025-02-20        West        Tables   8228    4    7910
# 1         2 2025-05-29       South         Chair   1149    8   -9739
# 2         3 2025-04-25        West        Laptop   1834    1    2909
# 3         4 2025-05-14       South        Laptop   4798    9   -9773
# 4         5 2025-07-18        West  Mobile Phone    808    8    -714
# 5         6 2025-06-04       South        Laptop   2247    1    4236
# 6         7 2025-04-25       North        Laptop   5817    1   -9774
# 7         8 2025-05-29       South        Laptop   5222    8    6899
# 8         9 2025-05-16        West        Laptop   8055    2    8965
# 9        10 2025-03-15        West       Charger   7242    9    1770

# %%
# table tail
table.tail(10)
# Out:
#      Order_id       Date Region Name  Product Name  sales  Qty  Profit
# 990       991 2025-03-21        East       Charger   9909    3   -4063
# 991       992 2025-01-05       South         Chair    510    9    1287
# 992       993 2025-05-10        East       Charger    759    4    -286
# 993       994 2025-02-14        East  Mobile Phone   2197    5    9238
# 994       995 2025-04-04        West        Laptop   8623    1   -8265
# 995       996 2025-03-19        West       Charger    634    8   -1530
# 996       997 2025-03-21        East  Mobile Phone   3845    7   -1280
# 997       998 2025-07-07        West        Tables   5013    3   -6158
# 998       999 2025-05-19       South        Laptop   5634    3    3146
# 999      1000 2025-03-11       North  Mobile Phone   7932    7   -5417

# %%
# table sample
table.sample(5)
# Out:
#      Order_id       Date Region Name  Product Name  sales  Qty  Profit
# 38         39 2025-03-22        West  Mobile Phone    617    7   -2229
# 390       391 2025-03-14       North       Charger   8032    1    5602
# 564       565 2025-04-30        West        Tables   2248    3    3367
# 595       596 2025-01-28       North        Tables   4232    6   -2616
# 516       517 2025-04-16        East  Mobile Phone    980    9    9940

# %%
# infomation:- about dataset

table.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Order_id      1000 non-null   int64
#  1   Date          1000 non-null   datetime64[ns]
#  2   Region Name   1000 non-null   object
#  3   Product Name  1000 non-null   object
#  4   sales         1000 non-null   int64
#  5   Qty           1000 non-null   int64
#  6   Profit        1000 non-null   int64
# dtypes: datetime64[ns](1), int64(4), object(2)
# memory usage: 54.8+ KB

# %%
# columns name
table.columns
# Out:
# Index(['Order_id', 'Date', 'Region Name', 'Product Name', 'sales', 'Qty',
#        'Profit'],
#       dtype='object')

# %%
# index
table.index
# Out:
# RangeIndex(start=0, stop=1000, step=1)

# %%
# isna() : it will check nan value counts

table.isna()
# Out:
#      Order_id   Date  Region Name  Product Name  sales    Qty  Profit
# 0       False  False        False         False  False  False   False
# 1       False  False        False         False  False  False   False
# 2       False  False        False         False  False  False   False
# 3       False  False        False         False  False  False   False
# 4       False  False        False         False  False  False   False
# ..        ...    ...          ...           ...    ...    ...     ...
# 995     False  False        False         False  False  False   False
# 996     False  False        False         False  False  False   False
# 997     False  False        False         False  False  False   False
# 998     False  False        False         False  False  False   False
# 999     False  False        False         False  False  False   False
#
# [1000 rows x 7 columns]

# %%
table.isna().value_counts()
# Out:
# Order_id  Date   Region Name  Product Name  sales  Qty    Profit
# False     False  False        False         False  False  False     1000
# Name: count, dtype: int64

# %%
table.isnull().value_counts()
# Out:
# Order_id  Date   Region Name  Product Name  sales  Qty    Profit
# False     False  False        False         False  False  False     1000
# Name: count, dtype: int64
